# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyabrat845/Machine-Learning/blob/main/Predicting_Heart_Disease_Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <u><b> Objective </b></u>
# ## <b> This project will focus on predicting heart disease using neural networks. Based on attributes such as blood pressure, cholestoral levels, heart rate, and other characteristic attributes, patients will be classified according to varying degrees of coronary artery disease. This project will utilize a dataset of 303 patients and distributed by the UCI Machine Learning Repository.
#
# ## <b>Machine learning and artificial intelligence is going to have a dramatic impact on the health field; as a result, familiarizing yourself with the data processing techniques appropriate for numerical health data and the most widely used algorithms for classification tasks is an incredibly valuable use of your time! </b>
#
# <br>
# <br>
#
# ## <b>Things to do :</b>
# * ### Read the heart.csv data, clean the data and normalise the features.
# * ### Split the data into train and test.
# * ### Use the keras package to build the model. The code to build such a model is provided below:
# * ### Evaluate the model across various metrics.

# %% [markdown]
# ## Explore the keras package to understand how the code works

# %%
# Loading in the data
import sklearn
from sklearn.datasets import load_breast_cancer 
# Visualization
import matplotlib as mpl   
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import pandas as pd


# Building the network 
import numpy as np

# Progress Bar
import tqdm as tqdm

import warnings
warnings.filterwarnings("ignore") #supresses warnings

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read the csv data
filepath = "/content/drive/MyDrive/Rough works/heart.csv"
heart_df = pd.read_csv(filepath)
heart_df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1   37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2   41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3   56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4   57    0   0       120   354    0  ...      1      0.6      2   0     2       1
#
# [5 rows x 14 columns]

# %%
heart_df.shape
# Out:
# (303, 14)

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# From above we conclude that their is no NULL values in our dataset.

# %%
heart_df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
count = sns.countplot(x='target', data=heart_df)
count.set_title("Heart disease distribution")
count.set_xticklabels(['No Heart disease', 'Heart Disease'])
plt.xlabel("");

# %%
count = sns.countplot(x='ca', data=heart_df)
count.set_title("Arteries")
count.set_xticklabels(['0','1','2','3','4'])
plt.xlabel("");

# %%
count = sns.countplot(x='target', data=heart_df,hue='sex')
plt.legend(['Female', 'Male'])
count.set_title("Heart disease by gender")
count.set_xticklabels(['No Heart disease', 'Heart Disease'])
plt.xlabel("");

# %%
hist = heart_df.hist(bins=10, figsize=(16,10))

# %% [markdown]
# ## **Scale the data**

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
scaler = MinMaxScaler()

# %%
X=scaler.fit_transform(heart_df.drop('target',axis=1))
Y=heart_df['target']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=0)

# %% [markdown]
# ## **Use keras package to train the data**

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.layers import Dropout
from keras import regularizers

# define a function to build the keras model
def create_model(a,b):
    # create model
   
    model = Sequential()
    model.add(Dense(a, input_dim=13, activation='sigmoid'))
    model.add(Dense(b, activation='sigmoid'))
    model.add(Dense(1, activation='sigmoid'))
    
    # compile model
    adam = Adam(lr=0.001)
    model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    return model

# %%
model = create_model(10,10)
model.fit(X_train, y_train, epochs=1000, verbose=2)
# Out:
# Epoch 1/1000
# 7/7 - 14s - loss: 0.6924 - accuracy: 0.5566
# Epoch 2/1000
# 7/7 - 0s - loss: 0.6907 - accuracy: 0.5566
# Epoch 3/1000
# 7/7 - 0s - loss: 0.6897 - accuracy: 0.5566
# Epoch 4/1000
# 7/7 - 0s - loss: 0.6890 - accuracy: 0.5566
# Epoch 5/1000
# 7/7 - 0s - loss: 0.6881 - accuracy: 0.5566
# Epoch 6/1000
# 7/7 - 0s - loss: 0.6874 - accuracy: 0.5566
# Epoch 7/1000
# 7/7 - 0s - loss: 0.6871 - accuracy: 0.5566
# Epoch 8/1000
# 7/7 - 0s - loss: 0.6860 - accuracy: 0.5566
# Epoch 9/1000
# 7/7 - 0s - loss: 0.6848 - accuracy: 0.5566
# Epoch 10/1000
# 7/7 - 0s - loss: 0.6843 - accuracy: 0.5566
# Epoch 11/1000
# 7/7 - 0s - loss: 0.6832 - accuracy: 0.5566
# Epoch 12/1000
# 7/7 - 0s - loss: 0.6828 - accuracy: 0.5566
# Epoch 13/1000
# 7/7 - 0s - loss: 0.6821 - accuracy: 0.5566
# Epoch 14/1000
# 7/7 - 0s - loss: 0.6810 - accuracy: 0.5566
# Epoch 15/1000
# 7/7 - 0s - loss: 0.6800 - accuracy: 0.5566
# Epoch 16/1000
# 7/7 - 0s - loss: 0.6791 - accuracy: 0.5566
# Epoch 17/1000
# 7/7 - 0s - loss: 0.6785 - accuracy: 0.5566
# Epoch 18/1000
# 7/7 - 0s - loss: 0.6773 - accuracy: 0.5566
# Epoch 19/1000
# 7/7 - 0s - loss: 0.6767 - accuracy: 0.5566
# Epoch 20/1000
# 7/7 - 0s - loss: 0.6757 - accuracy: 0.5566
# Epoch 21/1000
# 7/7 - 0s - loss: 0.6747 - accuracy: 0.5566
# Epoch 22/1000
# 7/7 - 0s - loss: 0.6733 - accuracy: 0.5566
# Epoch 23/1000
# 7/7 - 0s - loss: 0.6724 - accuracy: 0.5566
# Epoch 24/1000
# 7/7 - 0s - loss: 0.6714 - accuracy: 0.5566
# Epoch 25/1000
# 7/7 - 0s - loss: 0.6706 - accuracy: 0.5566
# Epoch 26/1000
# 7/7 - 0s - loss: 0.6695 - accuracy: 0.5566
# Epoch 27/1000
# 7/7 - 0s - loss: 0.6681 - accuracy: 0.5566
# Epoch 28/1000
# 7/7 - 0s - loss: 0.6668 - accuracy: 0.5566
# Epoch 29/1000
# 7/7 - 0s - loss: 0.6657 - accuracy: 0.5566
# Epoch 30/1000
# 7/7 - 0s - loss: 0.6640 - accuracy: 0.5566
# Epoch 31/1000
# 7/7 - 0s - loss: 0.6638 - accuracy: 0.5566
# Epoch 32/1000
# 7/7 - 0s - loss: 0.6616 - accuracy: 0.5566
# Epoch 33/1000
# 7/7 - 0s - loss: 0.6604 - accuracy: 0.5566
# Epoch 34/1000
# 7/7 - 0s - loss: 0.6588 - accuracy: 0.5566
# Epoch 35/1000
# 7/7 - 0s - loss: 0.6580 - accuracy: 0.5566
# Epoch 36/1000
# 7/7 - 0s - loss: 0.6559 - accuracy: 0.5566
# Epoch 37/1000
# 7/7 - 0s - loss: 0.6544 - accuracy: 0.5566
# Epoch 38/1000
# 7/7 - 0s - loss: 0.6531 - accuracy: 0.5566
# Epoch 39/1000
# 7/7 - 0s - loss: 0.6513 - accuracy: 0.5660
# Epoch 40/1000
# 7/7 - 0s - loss: 0.6494 - accuracy: 0.5755
# Epoch 41/1000
# 7/7 - 0s - loss: 0.6479 - accuracy: 0.5708
# Epoch 42/1000
# 7/7 - 0s - loss: 0.6466 - accuracy: 0.6038
# Epoch 43/1000
# 7/7 - 0s - loss: 0.6441 - accuracy: 0.6368
# Epoch 44/1000
# 7/7 - 0s - loss: 0.6420 - accuracy: 0.5943
# Epoch 45/1000
# 7/7 - 0s - loss: 0.6403 - accuracy: 0.6179
# Epoch 46/1000
# 7/7 - 0s - loss: 0.6391 - accuracy: 0.6462
# Epoch 47/1000
# 7/7 - 0s - loss: 0.6365 - accuracy: 0.6792
# Epoch 48/1000
# 7/7 - 0s - loss: 0.6346 - accuracy: 0.6557
# Epoch 49/1000
# 7/7 - 0s - loss: 0.6327 - accuracy: 0.6887
# Epoch 50/1000
# 7/7 - 0s - loss: 0.6305 - accuracy: 0.6745
# Epoch 51/1000
# 7/7 - 0s - loss: 0.6283 - accuracy: 0.6934
# Epoch 52/1000
# 7/7 - 0s - loss: 0.6260 - accuracy: 0.7123
# Epoch 53/1000
# 7/7 - 0s - loss: 0.6239 - accuracy: 0.7217
# Epoch 54/1000
# 7/7 - 0s - loss: 0.6219 - accuracy: 0.7170
# Epoch 55/1000
# 7/7 - 0s - loss: 0.6198 - accuracy: 0.7358
# Epoch 56/1000
# 7/7 - 0s - loss: 0.6170 - accuracy: 0.7358
# Epoch 57/1000
# 7/7 - 0s - loss: 0.6145 - accuracy: 0.7406
# Epoch 58/1000
# 7/7 - 0s - loss: 0.6117 - accuracy: 0.7453
# Epoch 59/1000
# 7/7 - 0s - loss: 0.6092 - accuracy: 0.7642
# Epoch 60/1000
# 7/7 - 0s - loss: 0.6063 - accuracy: 0.7594
# Epoch 61/1000
# 7/7 - 0s - loss: 0.6038 - accuracy: 0.7689
# Epoch 62/1000
# 7/7 - 0s - loss: 0.6007 - accuracy: 0.7783
# Epoch 63/1000
# 7/7 - 0s - loss: 0.5978 - accuracy: 0.7689
# Epoch 64/1000
# 7/7 - 0s - loss: 0.5949 - accuracy: 0.7877
# Epoch 65/1000
# 7/7 - 0s - loss: 0.5916 - accuracy: 0.7830
# Epoch 66/1000
# 7/7 - 0s - loss: 0.5889 - accuracy: 0.7877
# Epoch 67/1000
# 7/7 - 0s - loss: 0.5858 - accuracy: 0.7925
# Epoch 68/1000
# 7/7 - 0s - loss: 0.5826 - accuracy: 0.7925
# Epoch 69/1000
# 7/7 - 0s - loss: 0.5794 - accuracy: 0.7925
# Epoch 70/1000
# 7/7 - 0s - loss: 0.5763 - accuracy: 0.8160
# Epoch 71/1000
# 7/7 - 0s - loss: 0.5730 - accuracy: 0.8208
# Epoch 72/1000
# 7/7 - 0s - loss: 0.5697 - accuracy: 0.8302
# Epoch 73/1000
# 7/7 - 0s - loss: 0.5666 - accuracy: 0.8160
# Epoch 74/1000
# 7/7 - 0s - loss: 0.5634 - accuracy: 0.8302
# Epoch 75/1000
# 7/7 - 0s - loss: 0.5602 - accuracy: 0.8349
# Epoch 76/1000
# 7/7 - 0s - loss: 0.5567 - accuracy: 0.8349
# Epoch 77/1000
# 7/7 - 0s - loss: 0.5535 - accuracy: 0.8349
# Epoch 78/1000
# 7/7 - 0s - loss: 0.5497 - accuracy: 0.8396
# Epoch 79/1000
# 7/7 - 0s - loss: 0.5468 - accuracy: 0.8302
# Epoch 80/1000
# 7/7 - 0s - loss: 0.5436 - accuracy: 0.8396
# Epoch 81/1000
# 7/7 - 0s - loss: 0.5402 - accuracy: 0.8349
# Epoch 82/1000
# 7/7 - 0s - loss: 0.5371 - accuracy: 0.8302
# Epoch 83/1000
# 7/7 - 0s - loss: 0.5340 - accuracy: 0.8396
# Epoch 84/1000
# 7/7 - 0s - loss: 0.5303 - accuracy: 0.8396
# Epoch 85/1000
# 7/7 - 0s - loss: 0.5268 - accuracy: 0.8443
# Epoch 86/1000
# 7/7 - 0s - loss: 0.5237 - accuracy: 0.8443
# Epoch 87/1000
# 7/7 - 0s - loss: 0.5200 - accuracy: 0.8396
# Epoch 88/1000
# 7/7 - 0s - loss: 0.5167 - accuracy: 0.8443
# Epoch 89/1000
# 7/7 - 0s - loss: 0.5128 - accuracy: 0.8443
# Epoch 90/1000
# 7/7 - 0s - loss: 0.5092 - accuracy: 0.8396
# Epoch 91/1000
# 7/7 - 0s - loss: 0.5056 - accuracy: 0.8396
# Epoch 92/1000
# 7/7 - 0s - loss: 0.5019 - accuracy: 0.8396
# Epoch 93/1000
# 7/7 - 0s - loss: 0.4990 - accuracy: 0.8491
# Epoch 94/1000
# 7/7 - 0s - loss: 0.4956 - accuracy: 0.8349
# Epoch 95/1000
# 7/7 - 0s - loss: 0.4925 - accuracy: 0.8396
# Epoch 96/1000
# 7/7 - 0s - loss: 0.4897 - accuracy: 0.8396
# Epoch 97/1000
# 7/7 - 0s - loss: 0.4864 - accuracy: 0.8396
# Epoch 98/1000
# 7/7 - 0s - loss: 0.4836 - accuracy: 0.8349
# Epoch 99/1000
# 7/7 - 0s - loss: 0.4809 - accuracy: 0.8396
# Epoch 100/1000
# 7/7 - 0s - loss: 0.4775 - accuracy: 0.8396
# Epoch 101/1000
# 7/7 - 0s - loss: 0.4746 - accuracy: 0.8396
# Epoch 102/1000
# 7/7 - 0s - loss: 0.4711 - accuracy: 0.8491
# Epoch 103/1000
# 7/7 - 0s - loss: 0.4687 - accuracy: 0.8443
# Epoch 104/1000
# 7/7 - 0s - loss: 0.4656 - accuracy: 0.8396
# Epoch 105/1000
# 7/7 - 0s - loss: 0.4632 - accuracy: 0.8302
# Epoch 106/1000
# 7/7 - 0s - loss: 0.4603 - accuracy: 0.8349
# Epoch 107/1000
# 7/7 - 0s - loss: 0.4579 - accuracy: 0.8443
# Epoch 108/1000
# 7/7 - 0s - loss: 0.4557 - accuracy: 0.8443
# Epoch 109/1000
# 7/7 - 0s - loss: 0.4532 - accuracy: 0.8349
# Epoch 110/1000
# 7/7 - 0s - loss: 0.4510 - accuracy: 0.8349
# Epoch 111/1000
# 7/7 - 0s - loss: 0.4481 - accuracy: 0.8349
# Epoch 112/1000
# 7/7 - 0s - loss: 0.4455 - accuracy: 0.8349
# Epoch 113/1000
# 7/7 - 0s - loss: 0.4433 - accuracy: 0.8302
# Epoch 114/1000
# 7/7 - 0s - loss: 0.4406 - accuracy: 0.8349
# Epoch 115/1000
# 7/7 - 0s - loss: 0.4388 - accuracy: 0.8302
# Epoch 116/1000
# 7/7 - 0s - loss: 0.4360 - accuracy: 0.8302
# Epoch 117/1000
# 7/7 - 0s - loss: 0.4340 - accuracy: 0.8349
# Epoch 118/1000
# 7/7 - 0s - loss: 0.4316 - accuracy: 0.8302
# Epoch 119/1000
# 7/7 - 0s - loss: 0.4298 - accuracy: 0.8349
# Epoch 120/1000
# 7/7 - 0s - loss: 0.4281 - accuracy: 0.8302
# Epoch 121/1000
# 7/7 - 0s - loss: 0.4257 - accuracy: 0.8302
# Epoch 122/1000
# 7/7 - 0s - loss: 0.4242 - accuracy: 0.8302
# Epoch 123/1000
# 7/7 - 0s - loss: 0.4223 - accuracy: 0.8349
# Epoch 124/1000
# 7/7 - 0s - loss: 0.4204 - accuracy: 0.8302
# Epoch 125/1000
# 7/7 - 0s - loss: 0.4187 - accuracy: 0.8302
# Epoch 126/1000
# 7/7 - 0s - loss: 0.4188 - accuracy: 0.8349
# Epoch 127/1000
# 7/7 - 0s - loss: 0.4159 - accuracy: 0.8302
# Epoch 128/1000
# 7/7 - 0s - loss: 0.4144 - accuracy: 0.8302
# Epoch 129/1000
# 7/7 - 0s - loss: 0.4136 - accuracy: 0.8349
# Epoch 130/1000
# 7/7 - 0s - loss: 0.4118 - accuracy: 0.8396
# Epoch 131/1000
# 7/7 - 0s - loss: 0.4099 - accuracy: 0.8302
# Epoch 132/1000
# 7/7 - 0s - loss: 0.4084 - accuracy: 0.8302
# Epoch 133/1000
# 7/7 - 0s - loss: 0.4080 - accuracy: 0.8302
# Epoch 134/1000
# 7/7 - 0s - loss: 0.4062 - accuracy: 0.8349
# Epoch 135/1000
# 7/7 - 0s - loss: 0.4047 - accuracy: 0.8396
# Epoch 136/1000
# 7/7 - 0s - loss: 0.4030 - accuracy: 0.8349
# Epoch 137/1000
# 7/7 - 0s - loss: 0.4023 - accuracy: 0.8443
# Epoch 138/1000
# 7/7 - 0s - loss: 0.4006 - accuracy: 0.8349
# Epoch 139/1000
# 7/7 - 0s - loss: 0.3996 - accuracy: 0.8396
# Epoch 140/1000
# 7/7 - 0s - loss: 0.3982 - accuracy: 0.8396
# Epoch 141/1000
# 7/7 - 0s - loss: 0.3969 - accuracy: 0.8443
# Epoch 142/1000
# 7/7 - 0s - loss: 0.3960 - accuracy: 0.8302
# Epoch 143/1000
# 7/7 - 0s - loss: 0.3950 - accuracy: 0.8349
# Epoch 144/1000
# 7/7 - 0s - loss: 0.3933 - accuracy: 0.8396
# Epoch 145/1000
# 7/7 - 0s - loss: 0.3930 - accuracy: 0.8443
# Epoch 146/1000
# 7/7 - 0s - loss: 0.3913 - accuracy: 0.8349
# Epoch 147/1000
# 7/7 - 0s - loss: 0.3904 - accuracy: 0.8396
# Epoch 148/1000
# 7/7 - 0s - loss: 0.3897 - accuracy: 0.8491
# Epoch 149/1000
# 7/7 - 0s - loss: 0.3889 - accuracy: 0.8396
# Epoch 150/1000
# 7/7 - 0s - loss: 0.3881 - accuracy: 0.8443
# Epoch 151/1000
# 7/7 - 0s - loss: 0.3868 - accuracy: 0.8443
# Epoch 152/1000
# 7/7 - 0s - loss: 0.3862 - accuracy: 0.8443
# Epoch 153/1000
# 7/7 - 0s - loss: 0.3853 - accuracy: 0.8396
# Epoch 154/1000
# 7/7 - 0s - loss: 0.3851 - accuracy: 0.8538
# Epoch 155/1000
# 7/7 - 0s - loss: 0.3834 - accuracy: 0.8443
# Epoch 156/1000
# 7/7 - 0s - loss: 0.3825 - accuracy: 0.8491
# Epoch 157/1000
# 7/7 - 0s - loss: 0.3822 - accuracy: 0.8491
# Epoch 158/1000
# 7/7 - 0s - loss: 0.3815 - accuracy: 0.8443
# Epoch 159/1000
# 7/7 - 0s - loss: 0.3803 - accuracy: 0.8443
# Epoch 160/1000
# 7/7 - 0s - loss: 0.3797 - accuracy: 0.8491
# Epoch 161/1000
# 7/7 - 0s - loss: 0.3793 - accuracy: 0.8443
# Epoch 162/1000
# 7/7 - 0s - loss: 0.3786 - accuracy: 0.8491
# Epoch 163/1000
# 7/7 - 0s - loss: 0.3781 - accuracy: 0.8491
# Epoch 164/1000
# 7/7 - 0s - loss: 0.3771 - accuracy: 0.8491
# Epoch 165/1000
# 7/7 - 0s - loss: 0.3761 - accuracy: 0.8491
# Epoch 166/1000
# 7/7 - 0s - loss: 0.3762 - accuracy: 0.8491
# Epoch 167/1000
# 7/7 - 0s - loss: 0.3750 - accuracy: 0.8491
# Epoch 168/1000
# 7/7 - 0s - loss: 0.3747 - accuracy: 0.8443
# Epoch 169/1000
# 7/7 - 0s - loss: 0.3741 - accuracy: 0.8491
# Epoch 170/1000
# 7/7 - 0s - loss: 0.3744 - accuracy: 0.8443
# Epoch 171/1000
# 7/7 - 0s - loss: 0.3733 - accuracy: 0.8491
# Epoch 172/1000
# 7/7 - 0s - loss: 0.3722 - accuracy: 0.8538
# Epoch 173/1000
# 7/7 - 0s - loss: 0.3715 - accuracy: 0.8491
# Epoch 174/1000
# 7/7 - 0s - loss: 0.3721 - accuracy: 0.8491
# Epoch 175/1000
# 7/7 - 0s - loss: 0.3706 - accuracy: 0.8491
# Epoch 176/1000
# 7/7 - 0s - loss: 0.3706 - accuracy: 0.8491
# Epoch 177/1000
# 7/7 - 0s - loss: 0.3700 - accuracy: 0.8538
# Epoch 178/1000
# 7/7 - 0s - loss: 0.3707 - accuracy: 0.8491
# Epoch 179/1000
# 7/7 - 0s - loss: 0.3687 - accuracy: 0.8538
# Epoch 180/1000
# 7/7 - 0s - loss: 0.3691 - accuracy: 0.8538
# Epoch 181/1000
# 7/7 - 0s - loss: 0.3686 - accuracy: 0.8491
# Epoch 182/1000
# 7/7 - 0s - loss: 0.3679 - accuracy: 0.8585
# Epoch 183/1000
# 7/7 - 0s - loss: 0.3675 - accuracy: 0.8585
# Epoch 184/1000
# 7/7 - 0s - loss: 0.3677 - accuracy: 0.8538
# Epoch 185/1000
# 7/7 - 0s - loss: 0.3667 - accuracy: 0.8538
# Epoch 186/1000
# 7/7 - 0s - loss: 0.3660 - accuracy: 0.8538
# Epoch 187/1000
# 7/7 - 0s - loss: 0.3660 - accuracy: 0.8538
# Epoch 188/1000
# 7/7 - 0s - loss: 0.3656 - accuracy: 0.8538
# Epoch 189/1000
# 7/7 - 0s - loss: 0.3646 - accuracy: 0.8538
# Epoch 190/1000
# 7/7 - 0s - loss: 0.3650 - accuracy: 0.8538
# Epoch 191/1000
# 7/7 - 0s - loss: 0.3641 - accuracy: 0.8585
# Epoch 192/1000
# 7/7 - 0s - loss: 0.3641 - accuracy: 0.8585
# Epoch 193/1000
# 7/7 - 0s - loss: 0.3631 - accuracy: 0.8538
# Epoch 194/1000
# 7/7 - 0s - loss: 0.3634 - accuracy: 0.8585
# Epoch 195/1000
# 7/7 - 0s - loss: 0.3626 - accuracy: 0.8585
# Epoch 196/1000
# 7/7 - 0s - loss: 0.3621 - accuracy: 0.8585
# Epoch 197/1000
# 7/7 - 0s - loss: 0.3623 - accuracy: 0.8538
# Epoch 198/1000
# 7/7 - 0s - loss: 0.3616 - accuracy: 0.8585
# Epoch 199/1000
# 7/7 - 0s - loss: 0.3612 - accuracy: 0.8585
# Epoch 200/1000
# 7/7 - 0s - loss: 0.3608 - accuracy: 0.8585
# Epoch 201/1000
# 7/7 - 0s - loss: 0.3605 - accuracy: 0.8585
# Epoch 202/1000
# 7/7 - 0s - loss: 0.3597 - accuracy: 0.8585
# Epoch 203/1000
# 7/7 - 0s - loss: 0.3598 - accuracy: 0.8585
# Epoch 204/1000
# 7/7 - 0s - loss: 0.3591 - accuracy: 0.8585
# Epoch 205/1000
# 7/7 - 0s - loss: 0.3590 - accuracy: 0.8632
# Epoch 206/1000
# 7/7 - 0s - loss: 0.3585 - accuracy: 0.8632
# Epoch 207/1000
# 7/7 - 0s - loss: 0.3595 - accuracy: 0.8538
# Epoch 208/1000
# 7/7 - 0s - loss: 0.3582 - accuracy: 0.8538
# Epoch 209/1000
# 7/7 - 0s - loss: 0.3583 - accuracy: 0.8585
# Epoch 210/1000
# 7/7 - 0s - loss: 0.3572 - accuracy: 0.8632
# Epoch 211/1000
# 7/7 - 0s - loss: 0.3573 - accuracy: 0.8538
# Epoch 212/1000
# 7/7 - 0s - loss: 0.3569 - accuracy: 0.8632
# Epoch 213/1000
# 7/7 - 0s - loss: 0.3579 - accuracy: 0.8632
# Epoch 214/1000
# 7/7 - 0s - loss: 0.3575 - accuracy: 0.8585
# Epoch 215/1000
# 7/7 - 0s - loss: 0.3560 - accuracy: 0.8585
# Epoch 216/1000
# 7/7 - 0s - loss: 0.3561 - accuracy: 0.8632
# Epoch 217/1000
# 7/7 - 0s - loss: 0.3558 - accuracy: 0.8632
# Epoch 218/1000
# 7/7 - 0s - loss: 0.3560 - accuracy: 0.8632
# Epoch 219/1000
# 7/7 - 0s - loss: 0.3554 - accuracy: 0.8585
# Epoch 220/1000
# 7/7 - 0s - loss: 0.3562 - accuracy: 0.8585
# Epoch 221/1000
# 7/7 - 0s - loss: 0.3554 - accuracy: 0.8632
# Epoch 222/1000
# 7/7 - 0s - loss: 0.3556 - accuracy: 0.8632
# Epoch 223/1000
# 7/7 - 0s - loss: 0.3547 - accuracy: 0.8632
# Epoch 224/1000
# 7/7 - 0s - loss: 0.3548 - accuracy: 0.8632
# Epoch 225/1000
# 7/7 - 0s - loss: 0.3548 - accuracy: 0.8632
# Epoch 226/1000
# 7/7 - 0s - loss: 0.3541 - accuracy: 0.8632
# Epoch 227/1000
# 7/7 - 0s - loss: 0.3547 - accuracy: 0.8632
# Epoch 228/1000
# 7/7 - 0s - loss: 0.3541 - accuracy: 0.8585
# Epoch 229/1000
# 7/7 - 0s - loss: 0.3543 - accuracy: 0.8632
# Epoch 230/1000
# 7/7 - 0s - loss: 0.3539 - accuracy: 0.8632
# Epoch 231/1000
# 7/7 - 0s - loss: 0.3535 - accuracy: 0.8585
# Epoch 232/1000
# 7/7 - 0s - loss: 0.3527 - accuracy: 0.8538
# Epoch 233/1000
# 7/7 - 0s - loss: 0.3533 - accuracy: 0.8632
# Epoch 234/1000
# 7/7 - 0s - loss: 0.3531 - accuracy: 0.8538
# Epoch 235/1000
# 7/7 - 0s - loss: 0.3539 - accuracy: 0.8585
# Epoch 236/1000
# 7/7 - 0s - loss: 0.3524 - accuracy: 0.8632
# Epoch 237/1000
# 7/7 - 0s - loss: 0.3527 - accuracy: 0.8585
# Epoch 238/1000
# 7/7 - 0s - loss: 0.3526 - accuracy: 0.8491
# Epoch 239/1000
# 7/7 - 0s - loss: 0.3519 - accuracy: 0.8585
# Epoch 240/1000
# 7/7 - 0s - loss: 0.3526 - accuracy: 0.8585
# Epoch 241/1000
# 7/7 - 0s - loss: 0.3518 - accuracy: 0.8585
# Epoch 242/1000
# 7/7 - 0s - loss: 0.3516 - accuracy: 0.8538
# Epoch 243/1000
# 7/7 - 0s - loss: 0.3518 - accuracy: 0.8632
# Epoch 244/1000
# 7/7 - 0s - loss: 0.3521 - accuracy: 0.8538
# Epoch 245/1000
# 7/7 - 0s - loss: 0.3514 - accuracy: 0.8585
# Epoch 246/1000
# 7/7 - 0s - loss: 0.3515 - accuracy: 0.8632
# Epoch 247/1000
# 7/7 - 0s - loss: 0.3511 - accuracy: 0.8585
# Epoch 248/1000
# 7/7 - 0s - loss: 0.3508 - accuracy: 0.8585
# Epoch 249/1000
# 7/7 - 0s - loss: 0.3511 - accuracy: 0.8585
# Epoch 250/1000
# 7/7 - 0s - loss: 0.3504 - accuracy: 0.8585
# Epoch 251/1000
# 7/7 - 0s - loss: 0.3508 - accuracy: 0.8538
# Epoch 252/1000
# 7/7 - 0s - loss: 0.3504 - accuracy: 0.8585
# Epoch 253/1000
# 7/7 - 0s - loss: 0.3505 - accuracy: 0.8585
# Epoch 254/1000
# 7/7 - 0s - loss: 0.3500 - accuracy: 0.8538
# Epoch 255/1000
# 7/7 - 0s - loss: 0.3499 - accuracy: 0.8585
# Epoch 256/1000
# 7/7 - 0s - loss: 0.3498 - accuracy: 0.8679
# Epoch 257/1000
# 7/7 - 0s - loss: 0.3496 - accuracy: 0.8632
# Epoch 258/1000
# 7/7 - 0s - loss: 0.3493 - accuracy: 0.8632
# Epoch 259/1000
# 7/7 - 0s - loss: 0.3502 - accuracy: 0.8632
# Epoch 260/1000
# 7/7 - 0s - loss: 0.3497 - accuracy: 0.8585
# Epoch 261/1000
# 7/7 - 0s - loss: 0.3490 - accuracy: 0.8585
# Epoch 262/1000
# 7/7 - 0s - loss: 0.3491 - accuracy: 0.8632
# Epoch 263/1000
# 7/7 - 0s - loss: 0.3498 - accuracy: 0.8538
# Epoch 264/1000
# 7/7 - 0s - loss: 0.3483 - accuracy: 0.8632
# Epoch 265/1000
# 7/7 - 0s - loss: 0.3499 - accuracy: 0.8632
# Epoch 266/1000
# 7/7 - 0s - loss: 0.3482 - accuracy: 0.8679
# Epoch 267/1000
# 7/7 - 0s - loss: 0.3481 - accuracy: 0.8585
# Epoch 268/1000
# 7/7 - 0s - loss: 0.3488 - accuracy: 0.8679
# Epoch 269/1000
# 7/7 - 0s - loss: 0.3487 - accuracy: 0.8538
# Epoch 270/1000
# 7/7 - 0s - loss: 0.3480 - accuracy: 0.8538
# Epoch 271/1000
# 7/7 - 0s - loss: 0.3488 - accuracy: 0.8585
# Epoch 272/1000
# 7/7 - 0s - loss: 0.3482 - accuracy: 0.8585
# Epoch 273/1000
# 7/7 - 0s - loss: 0.3476 - accuracy: 0.8538
# Epoch 274/1000
# 7/7 - 0s - loss: 0.3482 - accuracy: 0.8585
# Epoch 275/1000
# 7/7 - 0s - loss: 0.3474 - accuracy: 0.8679
# Epoch 276/1000
# 7/7 - 0s - loss: 0.3476 - accuracy: 0.8679
# Epoch 277/1000
# 7/7 - 0s - loss: 0.3471 - accuracy: 0.8585
# Epoch 278/1000
# 7/7 - 0s - loss: 0.3476 - accuracy: 0.8538
# Epoch 279/1000
# 7/7 - 0s - loss: 0.3479 - accuracy: 0.8585
# Epoch 280/1000
# 7/7 - 0s - loss: 0.3472 - accuracy: 0.8632
# Epoch 281/1000
# 7/7 - 0s - loss: 0.3467 - accuracy: 0.8538
# Epoch 282/1000
# 7/7 - 0s - loss: 0.3473 - accuracy: 0.8632
# Epoch 283/1000
# 7/7 - 0s - loss: 0.3473 - accuracy: 0.8632
# Epoch 284/1000
# 7/7 - 0s - loss: 0.3467 - accuracy: 0.8679
# Epoch 285/1000
# 7/7 - 0s - loss: 0.3479 - accuracy: 0.8585
# Epoch 286/1000
# 7/7 - 0s - loss: 0.3469 - accuracy: 0.8632
# Epoch 287/1000
# 7/7 - 0s - loss: 0.3465 - accuracy: 0.8491
# Epoch 288/1000
# 7/7 - 0s - loss: 0.3461 - accuracy: 0.8632
# Epoch 289/1000
# 7/7 - 0s - loss: 0.3463 - accuracy: 0.8632
# Epoch 290/1000
# 7/7 - 0s - loss: 0.3467 - accuracy: 0.8679
# Epoch 291/1000
# 7/7 - 0s - loss: 0.3460 - accuracy: 0.8585
# Epoch 292/1000
# 7/7 - 0s - loss: 0.3463 - accuracy: 0.8632
# Epoch 293/1000
# 7/7 - 0s - loss: 0.3459 - accuracy: 0.8632
# Epoch 294/1000
# 7/7 - 0s - loss: 0.3457 - accuracy: 0.8679
# Epoch 295/1000
# 7/7 - 0s - loss: 0.3463 - accuracy: 0.8679
# Epoch 296/1000
# 7/7 - 0s - loss: 0.3455 - accuracy: 0.8632
# Epoch 297/1000
# 7/7 - 0s - loss: 0.3462 - accuracy: 0.8632
# Epoch 298/1000
# 7/7 - 0s - loss: 0.3460 - accuracy: 0.8632
# Epoch 299/1000
# 7/7 - 0s - loss: 0.3460 - accuracy: 0.8632
# Epoch 300/1000
# 7/7 - 0s - loss: 0.3458 - accuracy: 0.8632
# Epoch 301/1000
# 7/7 - 0s - loss: 0.3453 - accuracy: 0.8632
# Epoch 302/1000
# 7/7 - 0s - loss: 0.3455 - accuracy: 0.8632
# Epoch 303/1000
# 7/7 - 0s - loss: 0.3462 - accuracy: 0.8679
# Epoch 304/1000
# 7/7 - 0s - loss: 0.3454 - accuracy: 0.8585
# Epoch 305/1000
# 7/7 - 0s - loss: 0.3448 - accuracy: 0.8679
# Epoch 306/1000
# 7/7 - 0s - loss: 0.3452 - accuracy: 0.8632
# Epoch 307/1000
# 7/7 - 0s - loss: 0.3448 - accuracy: 0.8585
# Epoch 308/1000
# 7/7 - 0s - loss: 0.3454 - accuracy: 0.8679
# Epoch 309/1000
# 7/7 - 0s - loss: 0.3445 - accuracy: 0.8679
# Epoch 310/1000
# 7/7 - 0s - loss: 0.3448 - accuracy: 0.8679
# Epoch 311/1000
# 7/7 - 0s - loss: 0.3447 - accuracy: 0.8632
# Epoch 312/1000
# 7/7 - 0s - loss: 0.3449 - accuracy: 0.8632
# Epoch 313/1000
# 7/7 - 0s - loss: 0.3445 - accuracy: 0.8679
# Epoch 314/1000
# 7/7 - 0s - loss: 0.3443 - accuracy: 0.8679
# Epoch 315/1000
# 7/7 - 0s - loss: 0.3444 - accuracy: 0.8679
# Epoch 316/1000
# 7/7 - 0s - loss: 0.3444 - accuracy: 0.8632
# Epoch 317/1000
# 7/7 - 0s - loss: 0.3439 - accuracy: 0.8632
# Epoch 318/1000
# 7/7 - 0s - loss: 0.3441 - accuracy: 0.8632
# Epoch 319/1000
# 7/7 - 0s - loss: 0.3439 - accuracy: 0.8679
# Epoch 320/1000
# 7/7 - 0s - loss: 0.3438 - accuracy: 0.8679
# Epoch 321/1000
# 7/7 - 0s - loss: 0.3438 - accuracy: 0.8632
# Epoch 322/1000
# 7/7 - 0s - loss: 0.3441 - accuracy: 0.8585
# Epoch 323/1000
# 7/7 - 0s - loss: 0.3439 - accuracy: 0.8585
# Epoch 324/1000
# 7/7 - 0s - loss: 0.3435 - accuracy: 0.8632
# Epoch 325/1000
# 7/7 - 0s - loss: 0.3442 - accuracy: 0.8679
# Epoch 326/1000
# 7/7 - 0s - loss: 0.3435 - accuracy: 0.8632
# Epoch 327/1000
# 7/7 - 0s - loss: 0.3438 - accuracy: 0.8632
# Epoch 328/1000
# 7/7 - 0s - loss: 0.3440 - accuracy: 0.8632
# Epoch 329/1000
# 7/7 - 0s - loss: 0.3435 - accuracy: 0.8585
# Epoch 330/1000
# 7/7 - 0s - loss: 0.3439 - accuracy: 0.8679
# Epoch 331/1000
# 7/7 - 0s - loss: 0.3428 - accuracy: 0.8632
# Epoch 332/1000
# 7/7 - 0s - loss: 0.3429 - accuracy: 0.8726
# Epoch 333/1000
# 7/7 - 0s - loss: 0.3434 - accuracy: 0.8679
# Epoch 334/1000
# 7/7 - 0s - loss: 0.3428 - accuracy: 0.8632
# Epoch 335/1000
# 7/7 - 0s - loss: 0.3427 - accuracy: 0.8679
# Epoch 336/1000
# 7/7 - 0s - loss: 0.3435 - accuracy: 0.8632
# Epoch 337/1000
# 7/7 - 0s - loss: 0.3433 - accuracy: 0.8679
# Epoch 338/1000
# 7/7 - 0s - loss: 0.3430 - accuracy: 0.8679
# Epoch 339/1000
# 7/7 - 0s - loss: 0.3429 - accuracy: 0.8632
# Epoch 340/1000
# 7/7 - 0s - loss: 0.3424 - accuracy: 0.8679
# Epoch 341/1000
# 7/7 - 0s - loss: 0.3427 - accuracy: 0.8632
# Epoch 342/1000
# 7/7 - 0s - loss: 0.3429 - accuracy: 0.8632
# Epoch 343/1000
# 7/7 - 0s - loss: 0.3425 - accuracy: 0.8632
# Epoch 344/1000
# 7/7 - 0s - loss: 0.3427 - accuracy: 0.8632
# Epoch 345/1000
# 7/7 - 0s - loss: 0.3425 - accuracy: 0.8679
# Epoch 346/1000
# 7/7 - 0s - loss: 0.3426 - accuracy: 0.8632
# Epoch 347/1000
# 7/7 - 0s - loss: 0.3423 - accuracy: 0.8632
# Epoch 348/1000
# 7/7 - 0s - loss: 0.3423 - accuracy: 0.8632
# Epoch 349/1000
# 7/7 - 0s - loss: 0.3430 - accuracy: 0.8632
# Epoch 350/1000
# 7/7 - 0s - loss: 0.3423 - accuracy: 0.8632
# Epoch 351/1000
# 7/7 - 0s - loss: 0.3430 - accuracy: 0.8632
# Epoch 352/1000
# 7/7 - 0s - loss: 0.3416 - accuracy: 0.8632
# Epoch 353/1000
# 7/7 - 0s - loss: 0.3431 - accuracy: 0.8632
# Epoch 354/1000
# 7/7 - 0s - loss: 0.3418 - accuracy: 0.8632
# Epoch 355/1000
# 7/7 - 0s - loss: 0.3420 - accuracy: 0.8632
# Epoch 356/1000
# 7/7 - 0s - loss: 0.3418 - accuracy: 0.8632
# Epoch 357/1000
# 7/7 - 0s - loss: 0.3415 - accuracy: 0.8632
# Epoch 358/1000
# 7/7 - 0s - loss: 0.3421 - accuracy: 0.8632
# Epoch 359/1000
# 7/7 - 0s - loss: 0.3416 - accuracy: 0.8632
# Epoch 360/1000
# 7/7 - 0s - loss: 0.3417 - accuracy: 0.8632
# Epoch 361/1000
# 7/7 - 0s - loss: 0.3421 - accuracy: 0.8632
# Epoch 362/1000
# 7/7 - 0s - loss: 0.3416 - accuracy: 0.8632
# Epoch 363/1000
# 7/7 - 0s - loss: 0.3411 - accuracy: 0.8632
# Epoch 364/1000
# 7/7 - 0s - loss: 0.3412 - accuracy: 0.8632
# Epoch 365/1000
# 7/7 - 0s - loss: 0.3416 - accuracy: 0.8632
# Epoch 366/1000
# 7/7 - 0s - loss: 0.3413 - accuracy: 0.8632
# Epoch 367/1000
# 7/7 - 0s - loss: 0.3419 - accuracy: 0.8632
# Epoch 368/1000
# 7/7 - 0s - loss: 0.3407 - accuracy: 0.8632
# Epoch 369/1000
# 7/7 - 0s - loss: 0.3415 - accuracy: 0.8632
# Epoch 370/1000
# 7/7 - 0s - loss: 0.3415 - accuracy: 0.8679
# Epoch 371/1000
# 7/7 - 0s - loss: 0.3407 - accuracy: 0.8632
# Epoch 372/1000
# 7/7 - 0s - loss: 0.3414 - accuracy: 0.8632
# Epoch 373/1000
# 7/7 - 0s - loss: 0.3408 - accuracy: 0.8679
# Epoch 374/1000
# 7/7 - 0s - loss: 0.3407 - accuracy: 0.8726
# Epoch 375/1000
# 7/7 - 0s - loss: 0.3406 - accuracy: 0.8632
# Epoch 376/1000
# 7/7 - 0s - loss: 0.3411 - accuracy: 0.8632
# Epoch 377/1000
# 7/7 - 0s - loss: 0.3411 - accuracy: 0.8632
# Epoch 378/1000
# 7/7 - 0s - loss: 0.3413 - accuracy: 0.8632
# Epoch 379/1000
# 7/7 - 0s - loss: 0.3405 - accuracy: 0.8632
# Epoch 380/1000
# 7/7 - 0s - loss: 0.3408 - accuracy: 0.8632
# Epoch 381/1000
# 7/7 - 0s - loss: 0.3402 - accuracy: 0.8679
# Epoch 382/1000
# 7/7 - 0s - loss: 0.3410 - accuracy: 0.8632
# Epoch 383/1000
# 7/7 - 0s - loss: 0.3405 - accuracy: 0.8632
# Epoch 384/1000
# 7/7 - 0s - loss: 0.3403 - accuracy: 0.8632
# Epoch 385/1000
# 7/7 - 0s - loss: 0.3404 - accuracy: 0.8632
# Epoch 386/1000
# 7/7 - 0s - loss: 0.3410 - accuracy: 0.8632
# Epoch 387/1000
# 7/7 - 0s - loss: 0.3404 - accuracy: 0.8632
# Epoch 388/1000
# 7/7 - 0s - loss: 0.3405 - accuracy: 0.8632
# Epoch 389/1000
# 7/7 - 0s - loss: 0.3399 - accuracy: 0.8679
# Epoch 390/1000
# 7/7 - 0s - loss: 0.3410 - accuracy: 0.8726
# Epoch 391/1000
# 7/7 - 0s - loss: 0.3396 - accuracy: 0.8632
# Epoch 392/1000
# 7/7 - 0s - loss: 0.3409 - accuracy: 0.8679
# Epoch 393/1000
# 7/7 - 0s - loss: 0.3404 - accuracy: 0.8632
# Epoch 394/1000
# 7/7 - 0s - loss: 0.3397 - accuracy: 0.8632
# Epoch 395/1000
# 7/7 - 0s - loss: 0.3400 - accuracy: 0.8632
# Epoch 396/1000
# 7/7 - 0s - loss: 0.3399 - accuracy: 0.8726
# Epoch 397/1000
# 7/7 - 0s - loss: 0.3415 - accuracy: 0.8632
# Epoch 398/1000
# 7/7 - 0s - loss: 0.3394 - accuracy: 0.8632
# Epoch 399/1000
# 7/7 - 0s - loss: 0.3398 - accuracy: 0.8632
# Epoch 400/1000
# 7/7 - 0s - loss: 0.3395 - accuracy: 0.8679
# Epoch 401/1000
# 7/7 - 0s - loss: 0.3400 - accuracy: 0.8632
# Epoch 402/1000
# 7/7 - 0s - loss: 0.3391 - accuracy: 0.8632
# Epoch 403/1000
# 7/7 - 0s - loss: 0.3401 - accuracy: 0.8632
# Epoch 404/1000
# 7/7 - 0s - loss: 0.3392 - accuracy: 0.8632
# Epoch 405/1000
# 7/7 - 0s - loss: 0.3399 - accuracy: 0.8632
# Epoch 406/1000
# 7/7 - 0s - loss: 0.3395 - accuracy: 0.8632
# Epoch 407/1000
# 7/7 - 0s - loss: 0.3391 - accuracy: 0.8632
# Epoch 408/1000
# 7/7 - 0s - loss: 0.3394 - accuracy: 0.8632
# Epoch 409/1000
# 7/7 - 0s - loss: 0.3392 - accuracy: 0.8679
# Epoch 410/1000
# 7/7 - 0s - loss: 0.3393 - accuracy: 0.8632
# Epoch 411/1000
# 7/7 - 0s - loss: 0.3386 - accuracy: 0.8632
# Epoch 412/1000
# 7/7 - 0s - loss: 0.3391 - accuracy: 0.8632
# Epoch 413/1000
# 7/7 - 0s - loss: 0.3403 - accuracy: 0.8679
# Epoch 414/1000
# 7/7 - 0s - loss: 0.3392 - accuracy: 0.8632
# Epoch 415/1000
# 7/7 - 0s - loss: 0.3387 - accuracy: 0.8632
# Epoch 416/1000
# 7/7 - 0s - loss: 0.3394 - accuracy: 0.8679
# Epoch 417/1000
# 7/7 - 0s - loss: 0.3383 - accuracy: 0.8632
# Epoch 418/1000
# 7/7 - 0s - loss: 0.3383 - accuracy: 0.8632
# Epoch 419/1000
# 7/7 - 0s - loss: 0.3396 - accuracy: 0.8632
# Epoch 420/1000
# 7/7 - 0s - loss: 0.3385 - accuracy: 0.8632
# Epoch 421/1000
# 7/7 - 0s - loss: 0.3385 - accuracy: 0.8632
# Epoch 422/1000
# 7/7 - 0s - loss: 0.3391 - accuracy: 0.8632
# Epoch 423/1000
# 7/7 - 0s - loss: 0.3380 - accuracy: 0.8632
# Epoch 424/1000
# 7/7 - 0s - loss: 0.3387 - accuracy: 0.8632
# Epoch 425/1000
# 7/7 - 0s - loss: 0.3381 - accuracy: 0.8632
# Epoch 426/1000
# 7/7 - 0s - loss: 0.3390 - accuracy: 0.8632
# Epoch 427/1000
# 7/7 - 0s - loss: 0.3384 - accuracy: 0.8679
# Epoch 428/1000
# 7/7 - 0s - loss: 0.3385 - accuracy: 0.8679
# Epoch 429/1000
# 7/7 - 0s - loss: 0.3387 - accuracy: 0.8679
# Epoch 430/1000
# 7/7 - 0s - loss: 0.3383 - accuracy: 0.8632
# Epoch 431/1000
# 7/7 - 0s - loss: 0.3386 - accuracy: 0.8679
# Epoch 432/1000
# 7/7 - 0s - loss: 0.3380 - accuracy: 0.8632
# Epoch 433/1000
# 7/7 - 0s - loss: 0.3388 - accuracy: 0.8632
# Epoch 434/1000
# 7/7 - 0s - loss: 0.3378 - accuracy: 0.8632
# Epoch 435/1000
# 7/7 - 0s - loss: 0.3378 - accuracy: 0.8632
# Epoch 436/1000
# 7/7 - 0s - loss: 0.3381 - accuracy: 0.8632
# Epoch 437/1000
# 7/7 - 0s - loss: 0.3396 - accuracy: 0.8632
# Epoch 438/1000
# 7/7 - 0s - loss: 0.3380 - accuracy: 0.8632
# Epoch 439/1000
# 7/7 - 0s - loss: 0.3374 - accuracy: 0.8632
# Epoch 440/1000
# 7/7 - 0s - loss: 0.3378 - accuracy: 0.8632
# Epoch 441/1000
# 7/7 - 0s - loss: 0.3376 - accuracy: 0.8679
# Epoch 442/1000
# 7/7 - 0s - loss: 0.3375 - accuracy: 0.8632
# Epoch 443/1000
# 7/7 - 0s - loss: 0.3378 - accuracy: 0.8679
# Epoch 444/1000
# 7/7 - 0s - loss: 0.3381 - accuracy: 0.8679
# Epoch 445/1000
# 7/7 - 0s - loss: 0.3372 - accuracy: 0.8679
# Epoch 446/1000
# 7/7 - 0s - loss: 0.3373 - accuracy: 0.8679
# Epoch 447/1000
# 7/7 - 0s - loss: 0.3380 - accuracy: 0.8679
# Epoch 448/1000
# 7/7 - 0s - loss: 0.3374 - accuracy: 0.8632
# Epoch 449/1000
# 7/7 - 0s - loss: 0.3380 - accuracy: 0.8632
# Epoch 450/1000
# 7/7 - 0s - loss: 0.3372 - accuracy: 0.8632
# Epoch 451/1000
# 7/7 - 0s - loss: 0.3374 - accuracy: 0.8632
# Epoch 452/1000
# 7/7 - 0s - loss: 0.3377 - accuracy: 0.8632
# Epoch 453/1000
# 7/7 - 0s - loss: 0.3370 - accuracy: 0.8632
# Epoch 454/1000
# 7/7 - 0s - loss: 0.3376 - accuracy: 0.8679
# Epoch 455/1000
# 7/7 - 0s - loss: 0.3376 - accuracy: 0.8679
# Epoch 456/1000
# 7/7 - 0s - loss: 0.3372 - accuracy: 0.8679
# Epoch 457/1000
# 7/7 - 0s - loss: 0.3375 - accuracy: 0.8679
# Epoch 458/1000
# 7/7 - 0s - loss: 0.3369 - accuracy: 0.8679
# Epoch 459/1000
# 7/7 - 0s - loss: 0.3372 - accuracy: 0.8679
# Epoch 460/1000
# 7/7 - 0s - loss: 0.3370 - accuracy: 0.8632
# Epoch 461/1000
# 7/7 - 0s - loss: 0.3376 - accuracy: 0.8679
# Epoch 462/1000
# 7/7 - 0s - loss: 0.3371 - accuracy: 0.8632
# Epoch 463/1000
# 7/7 - 0s - loss: 0.3370 - accuracy: 0.8632
# Epoch 464/1000
# 7/7 - 0s - loss: 0.3367 - accuracy: 0.8632
# Epoch 465/1000
# 7/7 - 0s - loss: 0.3370 - accuracy: 0.8632
# Epoch 466/1000
# 7/7 - 0s - loss: 0.3366 - accuracy: 0.8632
# Epoch 467/1000
# 7/7 - 0s - loss: 0.3369 - accuracy: 0.8679
# Epoch 468/1000
# 7/7 - 0s - loss: 0.3369 - accuracy: 0.8679
# Epoch 469/1000
# 7/7 - 0s - loss: 0.3361 - accuracy: 0.8632
# Epoch 470/1000
# 7/7 - 0s - loss: 0.3365 - accuracy: 0.8632
# Epoch 471/1000
# 7/7 - 0s - loss: 0.3374 - accuracy: 0.8632
# Epoch 472/1000
# 7/7 - 0s - loss: 0.3362 - accuracy: 0.8632
# Epoch 473/1000
# 7/7 - 0s - loss: 0.3366 - accuracy: 0.8632
# Epoch 474/1000
# 7/7 - 0s - loss: 0.3365 - accuracy: 0.8679
# Epoch 475/1000
# 7/7 - 0s - loss: 0.3363 - accuracy: 0.8632
# Epoch 476/1000
# 7/7 - 0s - loss: 0.3363 - accuracy: 0.8632
# Epoch 477/1000
# 7/7 - 0s - loss: 0.3361 - accuracy: 0.8679
# Epoch 478/1000
# 7/7 - 0s - loss: 0.3359 - accuracy: 0.8632
# Epoch 479/1000
# 7/7 - 0s - loss: 0.3366 - accuracy: 0.8679
# Epoch 480/1000
# 7/7 - 0s - loss: 0.3367 - accuracy: 0.8679
# Epoch 481/1000
# 7/7 - 0s - loss: 0.3364 - accuracy: 0.8679
# Epoch 482/1000
# 7/7 - 0s - loss: 0.3356 - accuracy: 0.8679
# Epoch 483/1000
# 7/7 - 0s - loss: 0.3367 - accuracy: 0.8679
# Epoch 484/1000
# 7/7 - 0s - loss: 0.3360 - accuracy: 0.8679
# Epoch 485/1000
# 7/7 - 0s - loss: 0.3361 - accuracy: 0.8632
# Epoch 486/1000
# 7/7 - 0s - loss: 0.3359 - accuracy: 0.8679
# Epoch 487/1000
# 7/7 - 0s - loss: 0.3356 - accuracy: 0.8632
# Epoch 488/1000
# 7/7 - 0s - loss: 0.3369 - accuracy: 0.8726
# Epoch 489/1000
# 7/7 - 0s - loss: 0.3361 - accuracy: 0.8679
# Epoch 490/1000
# 7/7 - 0s - loss: 0.3358 - accuracy: 0.8726
# Epoch 491/1000
# 7/7 - 0s - loss: 0.3362 - accuracy: 0.8679
# Epoch 492/1000
# 7/7 - 0s - loss: 0.3357 - accuracy: 0.8632
# Epoch 493/1000
# 7/7 - 0s - loss: 0.3367 - accuracy: 0.8632
# Epoch 494/1000
# 7/7 - 0s - loss: 0.3357 - accuracy: 0.8726
# Epoch 495/1000
# 7/7 - 0s - loss: 0.3359 - accuracy: 0.8632
# Epoch 496/1000
# 7/7 - 0s - loss: 0.3353 - accuracy: 0.8679
# Epoch 497/1000
# 7/7 - 0s - loss: 0.3357 - accuracy: 0.8632
# Epoch 498/1000
# 7/7 - 0s - loss: 0.3363 - accuracy: 0.8679
# Epoch 499/1000
# 7/7 - 0s - loss: 0.3352 - accuracy: 0.8632
# Epoch 500/1000
# 7/7 - 0s - loss: 0.3354 - accuracy: 0.8679
# Epoch 501/1000
# 7/7 - 0s - loss: 0.3360 - accuracy: 0.8679
# Epoch 502/1000
# 7/7 - 0s - loss: 0.3358 - accuracy: 0.8726
# Epoch 503/1000
# 7/7 - 0s - loss: 0.3360 - accuracy: 0.8679
# Epoch 504/1000
# 7/7 - 0s - loss: 0.3355 - accuracy: 0.8679
# Epoch 505/1000
# 7/7 - 0s - loss: 0.3353 - accuracy: 0.8726
# Epoch 506/1000
# 7/7 - 0s - loss: 0.3356 - accuracy: 0.8632
# Epoch 507/1000
# 7/7 - 0s - loss: 0.3350 - accuracy: 0.8679
# Epoch 508/1000
# 7/7 - 0s - loss: 0.3353 - accuracy: 0.8632
# Epoch 509/1000
# 7/7 - 0s - loss: 0.3349 - accuracy: 0.8726
# Epoch 510/1000
# 7/7 - 0s - loss: 0.3358 - accuracy: 0.8679
# Epoch 511/1000
# 7/7 - 0s - loss: 0.3355 - accuracy: 0.8632
# Epoch 512/1000
# 7/7 - 0s - loss: 0.3348 - accuracy: 0.8679
# Epoch 513/1000
# 7/7 - 0s - loss: 0.3357 - accuracy: 0.8632
# Epoch 514/1000
# 7/7 - 0s - loss: 0.3351 - accuracy: 0.8679
# Epoch 515/1000
# 7/7 - 0s - loss: 0.3348 - accuracy: 0.8726
# Epoch 516/1000
# 7/7 - 0s - loss: 0.3347 - accuracy: 0.8679
# Epoch 517/1000
# 7/7 - 0s - loss: 0.3350 - accuracy: 0.8726
# Epoch 518/1000
# 7/7 - 0s - loss: 0.3359 - accuracy: 0.8632
# Epoch 519/1000
# 7/7 - 0s - loss: 0.3344 - accuracy: 0.8679
# Epoch 520/1000
# 7/7 - 0s - loss: 0.3353 - accuracy: 0.8632
# Epoch 521/1000
# 7/7 - 0s - loss: 0.3357 - accuracy: 0.8726
# Epoch 522/1000
# 7/7 - 0s - loss: 0.3352 - accuracy: 0.8679
# Epoch 523/1000
# 7/7 - 0s - loss: 0.3347 - accuracy: 0.8726
# Epoch 524/1000
# 7/7 - 0s - loss: 0.3344 - accuracy: 0.8679
# Epoch 525/1000
# 7/7 - 0s - loss: 0.3349 - accuracy: 0.8774
# Epoch 526/1000
# 7/7 - 0s - loss: 0.3348 - accuracy: 0.8679
# Epoch 527/1000
# 7/7 - 0s - loss: 0.3347 - accuracy: 0.8679
# Epoch 528/1000
# 7/7 - 0s - loss: 0.3347 - accuracy: 0.8679
# Epoch 529/1000
# 7/7 - 0s - loss: 0.3352 - accuracy: 0.8726
# Epoch 530/1000
# 7/7 - 0s - loss: 0.3351 - accuracy: 0.8679
# Epoch 531/1000
# 7/7 - 0s - loss: 0.3347 - accuracy: 0.8679
# Epoch 532/1000
# 7/7 - 0s - loss: 0.3340 - accuracy: 0.8774
# Epoch 533/1000
# 7/7 - 0s - loss: 0.3345 - accuracy: 0.8679
# Epoch 534/1000
# 7/7 - 0s - loss: 0.3347 - accuracy: 0.8679
# Epoch 535/1000
# 7/7 - 0s - loss: 0.3340 - accuracy: 0.8679
# Epoch 536/1000
# 7/7 - 0s - loss: 0.3350 - accuracy: 0.8679
# Epoch 537/1000
# 7/7 - 0s - loss: 0.3339 - accuracy: 0.8679
# Epoch 538/1000
# 7/7 - 0s - loss: 0.3339 - accuracy: 0.8726
# Epoch 539/1000
# 7/7 - 0s - loss: 0.3347 - accuracy: 0.8679
# Epoch 540/1000
# 7/7 - 0s - loss: 0.3349 - accuracy: 0.8726
# Epoch 541/1000
# 7/7 - 0s - loss: 0.3343 - accuracy: 0.8679
# Epoch 542/1000
# 7/7 - 0s - loss: 0.3338 - accuracy: 0.8679
# Epoch 543/1000
# 7/7 - 0s - loss: 0.3344 - accuracy: 0.8726
# Epoch 544/1000
# 7/7 - 0s - loss: 0.3342 - accuracy: 0.8679
# Epoch 545/1000
# 7/7 - 0s - loss: 0.3342 - accuracy: 0.8679
# Epoch 546/1000
# 7/7 - 0s - loss: 0.3341 - accuracy: 0.8726
# Epoch 547/1000
# 7/7 - 0s - loss: 0.3339 - accuracy: 0.8726
# Epoch 548/1000
# 7/7 - 0s - loss: 0.3337 - accuracy: 0.8679
# Epoch 549/1000
# 7/7 - 0s - loss: 0.3345 - accuracy: 0.8679
# Epoch 550/1000
# 7/7 - 0s - loss: 0.3338 - accuracy: 0.8632
# Epoch 551/1000
# 7/7 - 0s - loss: 0.3341 - accuracy: 0.8679
# Epoch 552/1000
# 7/7 - 0s - loss: 0.3333 - accuracy: 0.8679
# Epoch 553/1000
# 7/7 - 0s - loss: 0.3337 - accuracy: 0.8726
# Epoch 554/1000
# 7/7 - 0s - loss: 0.3335 - accuracy: 0.8679
# Epoch 555/1000
# 7/7 - 0s - loss: 0.3351 - accuracy: 0.8632
# Epoch 556/1000
# 7/7 - 0s - loss: 0.3340 - accuracy: 0.8679
# Epoch 557/1000
# 7/7 - 0s - loss: 0.3339 - accuracy: 0.8726
# Epoch 558/1000
# 7/7 - 0s - loss: 0.3341 - accuracy: 0.8726
# Epoch 559/1000
# 7/7 - 0s - loss: 0.3333 - accuracy: 0.8679
# Epoch 560/1000
# 7/7 - 0s - loss: 0.3339 - accuracy: 0.8726
# Epoch 561/1000
# 7/7 - 0s - loss: 0.3334 - accuracy: 0.8774
# Epoch 562/1000
# 7/7 - 0s - loss: 0.3341 - accuracy: 0.8679
# Epoch 563/1000
# 7/7 - 0s - loss: 0.3339 - accuracy: 0.8679
# Epoch 564/1000
# 7/7 - 0s - loss: 0.3334 - accuracy: 0.8679
# Epoch 565/1000
# 7/7 - 0s - loss: 0.3336 - accuracy: 0.8679
# Epoch 566/1000
# 7/7 - 0s - loss: 0.3331 - accuracy: 0.8679
# Epoch 567/1000
# 7/7 - 0s - loss: 0.3340 - accuracy: 0.8679
# Epoch 568/1000
# 7/7 - 0s - loss: 0.3343 - accuracy: 0.8679
# Epoch 569/1000
# 7/7 - 0s - loss: 0.3333 - accuracy: 0.8679
# Epoch 570/1000
# 7/7 - 0s - loss: 0.3331 - accuracy: 0.8726
# Epoch 571/1000
# 7/7 - 0s - loss: 0.3330 - accuracy: 0.8726
# Epoch 572/1000
# 7/7 - 0s - loss: 0.3333 - accuracy: 0.8679
# Epoch 573/1000
# 7/7 - 0s - loss: 0.3357 - accuracy: 0.8774
# Epoch 574/1000
# 7/7 - 0s - loss: 0.3328 - accuracy: 0.8679
# Epoch 575/1000
# 7/7 - 0s - loss: 0.3328 - accuracy: 0.8679
# Epoch 576/1000
# 7/7 - 0s - loss: 0.3336 - accuracy: 0.8679
# Epoch 577/1000
# 7/7 - 0s - loss: 0.3334 - accuracy: 0.8726
# Epoch 578/1000
# 7/7 - 0s - loss: 0.3332 - accuracy: 0.8726
# Epoch 579/1000
# 7/7 - 0s - loss: 0.3329 - accuracy: 0.8774
# Epoch 580/1000
# 7/7 - 0s - loss: 0.3330 - accuracy: 0.8679
# Epoch 581/1000
# 7/7 - 0s - loss: 0.3327 - accuracy: 0.8679
# Epoch 582/1000
# 7/7 - 0s - loss: 0.3338 - accuracy: 0.8679
# Epoch 583/1000
# 7/7 - 0s - loss: 0.3331 - accuracy: 0.8679
# Epoch 584/1000
# 7/7 - 0s - loss: 0.3335 - accuracy: 0.8774
# Epoch 585/1000
# 7/7 - 0s - loss: 0.3326 - accuracy: 0.8774
# Epoch 586/1000
# 7/7 - 0s - loss: 0.3335 - accuracy: 0.8821
# Epoch 587/1000
# 7/7 - 0s - loss: 0.3328 - accuracy: 0.8726
# Epoch 588/1000
# 7/7 - 0s - loss: 0.3338 - accuracy: 0.8726
# Epoch 589/1000
# 7/7 - 0s - loss: 0.3328 - accuracy: 0.8726
# Epoch 590/1000
# 7/7 - 0s - loss: 0.3332 - accuracy: 0.8726
# Epoch 591/1000
# 7/7 - 0s - loss: 0.3338 - accuracy: 0.8679
# Epoch 592/1000
# 7/7 - 0s - loss: 0.3327 - accuracy: 0.8726
# Epoch 593/1000
# 7/7 - 0s - loss: 0.3337 - accuracy: 0.8774
# Epoch 594/1000
# 7/7 - 0s - loss: 0.3328 - accuracy: 0.8774
# Epoch 595/1000
# 7/7 - 0s - loss: 0.3324 - accuracy: 0.8726
# Epoch 596/1000
# 7/7 - 0s - loss: 0.3330 - accuracy: 0.8774
# Epoch 597/1000
# 7/7 - 0s - loss: 0.3330 - accuracy: 0.8726
# Epoch 598/1000
# 7/7 - 0s - loss: 0.3326 - accuracy: 0.8679
# Epoch 599/1000
# 7/7 - 0s - loss: 0.3325 - accuracy: 0.8726
# Epoch 600/1000
# 7/7 - 0s - loss: 0.3328 - accuracy: 0.8726
# Epoch 601/1000
# 7/7 - 0s - loss: 0.3327 - accuracy: 0.8726
# Epoch 602/1000
# 7/7 - 0s - loss: 0.3325 - accuracy: 0.8821
# Epoch 603/1000
# 7/7 - 0s - loss: 0.3323 - accuracy: 0.8774
# Epoch 604/1000
# 7/7 - 0s - loss: 0.3336 - accuracy: 0.8726
# Epoch 605/1000
# 7/7 - 0s - loss: 0.3322 - accuracy: 0.8726
# Epoch 606/1000
# 7/7 - 0s - loss: 0.3332 - accuracy: 0.8774
# Epoch 607/1000
# 7/7 - 0s - loss: 0.3330 - accuracy: 0.8679
# Epoch 608/1000
# 7/7 - 0s - loss: 0.3324 - accuracy: 0.8679
# Epoch 609/1000
# 7/7 - 0s - loss: 0.3318 - accuracy: 0.8726
# Epoch 610/1000
# 7/7 - 0s - loss: 0.3323 - accuracy: 0.8679
# Epoch 611/1000
# 7/7 - 0s - loss: 0.3329 - accuracy: 0.8679
# Epoch 612/1000
# 7/7 - 0s - loss: 0.3326 - accuracy: 0.8679
# Epoch 613/1000
# 7/7 - 0s - loss: 0.3325 - accuracy: 0.8726
# Epoch 614/1000
# 7/7 - 0s - loss: 0.3319 - accuracy: 0.8679
# Epoch 615/1000
# 7/7 - 0s - loss: 0.3325 - accuracy: 0.8726
# Epoch 616/1000
# 7/7 - 0s - loss: 0.3328 - accuracy: 0.8679
# Epoch 617/1000
# 7/7 - 0s - loss: 0.3321 - accuracy: 0.8821
# Epoch 618/1000
# 7/7 - 0s - loss: 0.3333 - accuracy: 0.8726
# Epoch 619/1000
# 7/7 - 0s - loss: 0.3317 - accuracy: 0.8679
# Epoch 620/1000
# 7/7 - 0s - loss: 0.3320 - accuracy: 0.8726
# Epoch 621/1000
# 7/7 - 0s - loss: 0.3322 - accuracy: 0.8726
# Epoch 622/1000
# 7/7 - 0s - loss: 0.3320 - accuracy: 0.8726
# Epoch 623/1000
# 7/7 - 0s - loss: 0.3326 - accuracy: 0.8726
# Epoch 624/1000
# 7/7 - 0s - loss: 0.3321 - accuracy: 0.8679
# Epoch 625/1000
# 7/7 - 0s - loss: 0.3319 - accuracy: 0.8679
# Epoch 626/1000
# 7/7 - 0s - loss: 0.3316 - accuracy: 0.8726
# Epoch 627/1000
# 7/7 - 0s - loss: 0.3314 - accuracy: 0.8726
# Epoch 628/1000
# 7/7 - 0s - loss: 0.3318 - accuracy: 0.8726
# Epoch 629/1000
# 7/7 - 0s - loss: 0.3328 - accuracy: 0.8726
# Epoch 630/1000
# 7/7 - 0s - loss: 0.3316 - accuracy: 0.8726
# Epoch 631/1000
# 7/7 - 0s - loss: 0.3319 - accuracy: 0.8774
# Epoch 632/1000
# 7/7 - 0s - loss: 0.3318 - accuracy: 0.8726
# Epoch 633/1000
# 7/7 - 0s - loss: 0.3321 - accuracy: 0.8774
# Epoch 634/1000
# 7/7 - 0s - loss: 0.3324 - accuracy: 0.8679
# Epoch 635/1000
# 7/7 - 0s - loss: 0.3316 - accuracy: 0.8679
# Epoch 636/1000
# 7/7 - 0s - loss: 0.3315 - accuracy: 0.8679
# Epoch 637/1000
# 7/7 - 0s - loss: 0.3317 - accuracy: 0.8726
# Epoch 638/1000
# 7/7 - 0s - loss: 0.3315 - accuracy: 0.8679
# Epoch 639/1000
# 7/7 - 0s - loss: 0.3319 - accuracy: 0.8726
# Epoch 640/1000
# 7/7 - 0s - loss: 0.3327 - accuracy: 0.8821
# Epoch 641/1000
# 7/7 - 0s - loss: 0.3321 - accuracy: 0.8726
# Epoch 642/1000
# 7/7 - 0s - loss: 0.3315 - accuracy: 0.8726
# Epoch 643/1000
# 7/7 - 0s - loss: 0.3316 - accuracy: 0.8774
# Epoch 644/1000
# 7/7 - 0s - loss: 0.3319 - accuracy: 0.8726
# Epoch 645/1000
# 7/7 - 0s - loss: 0.3322 - accuracy: 0.8726
# Epoch 646/1000
# 7/7 - 0s - loss: 0.3315 - accuracy: 0.8726
# Epoch 647/1000
# 7/7 - 0s - loss: 0.3317 - accuracy: 0.8774
# Epoch 648/1000
# 7/7 - 0s - loss: 0.3312 - accuracy: 0.8726
# Epoch 649/1000
# 7/7 - 0s - loss: 0.3318 - accuracy: 0.8632
# Epoch 650/1000
# 7/7 - 0s - loss: 0.3313 - accuracy: 0.8632
# Epoch 651/1000
# 7/7 - 0s - loss: 0.3312 - accuracy: 0.8726
# Epoch 652/1000
# 7/7 - 0s - loss: 0.3315 - accuracy: 0.8726
# Epoch 653/1000
# 7/7 - 0s - loss: 0.3323 - accuracy: 0.8679
# Epoch 654/1000
# 7/7 - 0s - loss: 0.3314 - accuracy: 0.8679
# Epoch 655/1000
# 7/7 - 0s - loss: 0.3315 - accuracy: 0.8679
# Epoch 656/1000
# 7/7 - 0s - loss: 0.3310 - accuracy: 0.8679
# Epoch 657/1000
# 7/7 - 0s - loss: 0.3313 - accuracy: 0.8679
# Epoch 658/1000
# 7/7 - 0s - loss: 0.3317 - accuracy: 0.8679
# Epoch 659/1000
# 7/7 - 0s - loss: 0.3314 - accuracy: 0.8679
# Epoch 660/1000
# 7/7 - 0s - loss: 0.3313 - accuracy: 0.8679
# Epoch 661/1000
# 7/7 - 0s - loss: 0.3310 - accuracy: 0.8726
# Epoch 662/1000
# 7/7 - 0s - loss: 0.3313 - accuracy: 0.8726
# Epoch 663/1000
# 7/7 - 0s - loss: 0.3314 - accuracy: 0.8774
# Epoch 664/1000
# 7/7 - 0s - loss: 0.3313 - accuracy: 0.8726
# Epoch 665/1000
# 7/7 - 0s - loss: 0.3309 - accuracy: 0.8726
# Epoch 666/1000
# 7/7 - 0s - loss: 0.3318 - accuracy: 0.8679
# Epoch 667/1000
# 7/7 - 0s - loss: 0.3313 - accuracy: 0.8726
# Epoch 668/1000
# 7/7 - 0s - loss: 0.3309 - accuracy: 0.8726
# Epoch 669/1000
# 7/7 - 0s - loss: 0.3310 - accuracy: 0.8726
# Epoch 670/1000
# 7/7 - 0s - loss: 0.3312 - accuracy: 0.8679
# Epoch 671/1000
# 7/7 - 0s - loss: 0.3308 - accuracy: 0.8726
# Epoch 672/1000
# 7/7 - 0s - loss: 0.3314 - accuracy: 0.8726
# Epoch 673/1000
# 7/7 - 0s - loss: 0.3308 - accuracy: 0.8679
# Epoch 674/1000
# 7/7 - 0s - loss: 0.3315 - accuracy: 0.8632
# Epoch 675/1000
# 7/7 - 0s - loss: 0.3311 - accuracy: 0.8679
# Epoch 676/1000
# 7/7 - 0s - loss: 0.3319 - accuracy: 0.8679
# Epoch 677/1000
# 7/7 - 0s - loss: 0.3307 - accuracy: 0.8679
# Epoch 678/1000
# 7/7 - 0s - loss: 0.3308 - accuracy: 0.8679
# Epoch 679/1000
# 7/7 - 0s - loss: 0.3309 - accuracy: 0.8679
# Epoch 680/1000
# 7/7 - 0s - loss: 0.3309 - accuracy: 0.8726
# Epoch 681/1000
# 7/7 - 0s - loss: 0.3306 - accuracy: 0.8679
# Epoch 682/1000
# 7/7 - 0s - loss: 0.3315 - accuracy: 0.8632
# Epoch 683/1000
# 7/7 - 0s - loss: 0.3308 - accuracy: 0.8679
# Epoch 684/1000
# 7/7 - 0s - loss: 0.3306 - accuracy: 0.8726
# Epoch 685/1000
# 7/7 - 0s - loss: 0.3307 - accuracy: 0.8726
# Epoch 686/1000
# 7/7 - 0s - loss: 0.3310 - accuracy: 0.8726
# Epoch 687/1000
# 7/7 - 0s - loss: 0.3307 - accuracy: 0.8679
# Epoch 688/1000
# 7/7 - 0s - loss: 0.3303 - accuracy: 0.8679
# Epoch 689/1000
# 7/7 - 0s - loss: 0.3304 - accuracy: 0.8679
# Epoch 690/1000
# 7/7 - 0s - loss: 0.3306 - accuracy: 0.8679
# Epoch 691/1000
# 7/7 - 0s - loss: 0.3310 - accuracy: 0.8774
# Epoch 692/1000
# 7/7 - 0s - loss: 0.3310 - accuracy: 0.8679
# Epoch 693/1000
# 7/7 - 0s - loss: 0.3308 - accuracy: 0.8726
# Epoch 694/1000
# 7/7 - 0s - loss: 0.3310 - accuracy: 0.8679
# Epoch 695/1000
# 7/7 - 0s - loss: 0.3306 - accuracy: 0.8726
# Epoch 696/1000
# 7/7 - 0s - loss: 0.3309 - accuracy: 0.8679
# Epoch 697/1000
# 7/7 - 0s - loss: 0.3303 - accuracy: 0.8679
# Epoch 698/1000
# 7/7 - 0s - loss: 0.3309 - accuracy: 0.8726
# Epoch 699/1000
# 7/7 - 0s - loss: 0.3306 - accuracy: 0.8726
# Epoch 700/1000
# 7/7 - 0s - loss: 0.3303 - accuracy: 0.8774
# Epoch 701/1000
# 7/7 - 0s - loss: 0.3302 - accuracy: 0.8726
# Epoch 702/1000
# 7/7 - 0s - loss: 0.3305 - accuracy: 0.8726
# Epoch 703/1000
# 7/7 - 0s - loss: 0.3304 - accuracy: 0.8679
# Epoch 704/1000
# 7/7 - 0s - loss: 0.3308 - accuracy: 0.8726
# Epoch 705/1000
# 7/7 - 0s - loss: 0.3305 - accuracy: 0.8774
# Epoch 706/1000
# 7/7 - 0s - loss: 0.3304 - accuracy: 0.8774
# Epoch 707/1000
# 7/7 - 0s - loss: 0.3306 - accuracy: 0.8774
# Epoch 708/1000
# 7/7 - 0s - loss: 0.3304 - accuracy: 0.8679
# Epoch 709/1000
# 7/7 - 0s - loss: 0.3313 - accuracy: 0.8726
# Epoch 710/1000
# 7/7 - 0s - loss: 0.3300 - accuracy: 0.8774
# Epoch 711/1000
# 7/7 - 0s - loss: 0.3319 - accuracy: 0.8726
# Epoch 712/1000
# 7/7 - 0s - loss: 0.3304 - accuracy: 0.8679
# Epoch 713/1000
# 7/7 - 0s - loss: 0.3297 - accuracy: 0.8726
# Epoch 714/1000
# 7/7 - 0s - loss: 0.3303 - accuracy: 0.8726
# Epoch 715/1000
# 7/7 - 0s - loss: 0.3304 - accuracy: 0.8726
# Epoch 716/1000
# 7/7 - 0s - loss: 0.3306 - accuracy: 0.8726
# Epoch 717/1000
# 7/7 - 0s - loss: 0.3295 - accuracy: 0.8726
# Epoch 718/1000
# 7/7 - 0s - loss: 0.3307 - accuracy: 0.8679
# Epoch 719/1000
# 7/7 - 0s - loss: 0.3303 - accuracy: 0.8726
# Epoch 720/1000
# 7/7 - 0s - loss: 0.3306 - accuracy: 0.8679
# Epoch 721/1000
# 7/7 - 0s - loss: 0.3302 - accuracy: 0.8679
# Epoch 722/1000
# 7/7 - 0s - loss: 0.3304 - accuracy: 0.8726
# Epoch 723/1000
# 7/7 - 0s - loss: 0.3299 - accuracy: 0.8726
# Epoch 724/1000
# 7/7 - 0s - loss: 0.3299 - accuracy: 0.8726
# Epoch 725/1000
# 7/7 - 0s - loss: 0.3295 - accuracy: 0.8726
# Epoch 726/1000
# 7/7 - 0s - loss: 0.3299 - accuracy: 0.8726
# Epoch 727/1000
# 7/7 - 0s - loss: 0.3298 - accuracy: 0.8726
# Epoch 728/1000
# 7/7 - 0s - loss: 0.3301 - accuracy: 0.8726
# Epoch 729/1000
# 7/7 - 0s - loss: 0.3303 - accuracy: 0.8726
# Epoch 730/1000
# 7/7 - 0s - loss: 0.3305 - accuracy: 0.8679
# Epoch 731/1000
# 7/7 - 0s - loss: 0.3299 - accuracy: 0.8774
# Epoch 732/1000
# 7/7 - 0s - loss: 0.3300 - accuracy: 0.8679
# Epoch 733/1000
# 7/7 - 0s - loss: 0.3294 - accuracy: 0.8726
# Epoch 734/1000
# 7/7 - 0s - loss: 0.3299 - accuracy: 0.8774
# Epoch 735/1000
# 7/7 - 0s - loss: 0.3312 - accuracy: 0.8774
# Epoch 736/1000
# 7/7 - 0s - loss: 0.3297 - accuracy: 0.8726
# Epoch 737/1000
# 7/7 - 0s - loss: 0.3300 - accuracy: 0.8726
# Epoch 738/1000
# 7/7 - 0s - loss: 0.3296 - accuracy: 0.8726
# Epoch 739/1000
# 7/7 - 0s - loss: 0.3303 - accuracy: 0.8726
# Epoch 740/1000
# 7/7 - 0s - loss: 0.3295 - accuracy: 0.8774
# Epoch 741/1000
# 7/7 - 0s - loss: 0.3295 - accuracy: 0.8726
# Epoch 742/1000
# 7/7 - 0s - loss: 0.3301 - accuracy: 0.8679
# Epoch 743/1000
# 7/7 - 0s - loss: 0.3299 - accuracy: 0.8774
# Epoch 744/1000
# 7/7 - 0s - loss: 0.3301 - accuracy: 0.8726
# Epoch 745/1000
# 7/7 - 0s - loss: 0.3297 - accuracy: 0.8726
# Epoch 746/1000
# 7/7 - 0s - loss: 0.3302 - accuracy: 0.8726
# Epoch 747/1000
# 7/7 - 0s - loss: 0.3296 - accuracy: 0.8774
# Epoch 748/1000
# 7/7 - 0s - loss: 0.3306 - accuracy: 0.8726
# Epoch 749/1000
# 7/7 - 0s - loss: 0.3302 - accuracy: 0.8726
# Epoch 750/1000
# 7/7 - 0s - loss: 0.3292 - accuracy: 0.8774
# Epoch 751/1000
# 7/7 - 0s - loss: 0.3292 - accuracy: 0.8774
# Epoch 752/1000
# 7/7 - 0s - loss: 0.3297 - accuracy: 0.8774
# Epoch 753/1000
# 7/7 - 0s - loss: 0.3299 - accuracy: 0.8774
# Epoch 754/1000
# 7/7 - 0s - loss: 0.3299 - accuracy: 0.8774
# Epoch 755/1000
# 7/7 - 0s - loss: 0.3294 - accuracy: 0.8774
# Epoch 756/1000
# 7/7 - 0s - loss: 0.3295 - accuracy: 0.8726
# Epoch 757/1000
# 7/7 - 0s - loss: 0.3298 - accuracy: 0.8726
# Epoch 758/1000
# 7/7 - 0s - loss: 0.3290 - accuracy: 0.8726
# Epoch 759/1000
# 7/7 - 0s - loss: 0.3295 - accuracy: 0.8726
# Epoch 760/1000
# 7/7 - 0s - loss: 0.3296 - accuracy: 0.8821
# Epoch 761/1000
# 7/7 - 0s - loss: 0.3297 - accuracy: 0.8726
# Epoch 762/1000
# 7/7 - 0s - loss: 0.3297 - accuracy: 0.8726
# Epoch 763/1000
# 7/7 - 0s - loss: 0.3294 - accuracy: 0.8679
# Epoch 764/1000
# 7/7 - 0s - loss: 0.3287 - accuracy: 0.8726
# Epoch 765/1000
# 7/7 - 0s - loss: 0.3302 - accuracy: 0.8774
# Epoch 766/1000
# 7/7 - 0s - loss: 0.3289 - accuracy: 0.8774
# Epoch 767/1000
# 7/7 - 0s - loss: 0.3296 - accuracy: 0.8726
# Epoch 768/1000
# 7/7 - 0s - loss: 0.3297 - accuracy: 0.8774
# Epoch 769/1000
# 7/7 - 0s - loss: 0.3293 - accuracy: 0.8774
# Epoch 770/1000
# 7/7 - 0s - loss: 0.3299 - accuracy: 0.8726
# Epoch 771/1000
# 7/7 - 0s - loss: 0.3301 - accuracy: 0.8726
# Epoch 772/1000
# 7/7 - 0s - loss: 0.3294 - accuracy: 0.8726
# Epoch 773/1000
# 7/7 - 0s - loss: 0.3287 - accuracy: 0.8726
# Epoch 774/1000
# 7/7 - 0s - loss: 0.3290 - accuracy: 0.8821
# Epoch 775/1000
# 7/7 - 0s - loss: 0.3291 - accuracy: 0.8774
# Epoch 776/1000
# 7/7 - 0s - loss: 0.3292 - accuracy: 0.8774
# Epoch 777/1000
# 7/7 - 0s - loss: 0.3289 - accuracy: 0.8821
# Epoch 778/1000
# 7/7 - 0s - loss: 0.3293 - accuracy: 0.8726
# Epoch 779/1000
# 7/7 - 0s - loss: 0.3287 - accuracy: 0.8774
# Epoch 780/1000
# 7/7 - 0s - loss: 0.3286 - accuracy: 0.8774
# Epoch 781/1000
# 7/7 - 0s - loss: 0.3293 - accuracy: 0.8774
# Epoch 782/1000
# 7/7 - 0s - loss: 0.3293 - accuracy: 0.8679
# Epoch 783/1000
# 7/7 - 0s - loss: 0.3285 - accuracy: 0.8726
# Epoch 784/1000
# 7/7 - 0s - loss: 0.3294 - accuracy: 0.8774
# Epoch 785/1000
# 7/7 - 0s - loss: 0.3291 - accuracy: 0.8774
# Epoch 786/1000
# 7/7 - 0s - loss: 0.3292 - accuracy: 0.8726
# Epoch 787/1000
# 7/7 - 0s - loss: 0.3291 - accuracy: 0.8774
# Epoch 788/1000
# 7/7 - 0s - loss: 0.3294 - accuracy: 0.8774
# Epoch 789/1000
# 7/7 - 0s - loss: 0.3288 - accuracy: 0.8726
# Epoch 790/1000
# 7/7 - 0s - loss: 0.3296 - accuracy: 0.8774
# Epoch 791/1000
# 7/7 - 0s - loss: 0.3286 - accuracy: 0.8726
# Epoch 792/1000
# 7/7 - 0s - loss: 0.3284 - accuracy: 0.8726
# Epoch 793/1000
# 7/7 - 0s - loss: 0.3296 - accuracy: 0.8774
# Epoch 794/1000
# 7/7 - 0s - loss: 0.3291 - accuracy: 0.8726
# Epoch 795/1000
# 7/7 - 0s - loss: 0.3289 - accuracy: 0.8726
# Epoch 796/1000
# 7/7 - 0s - loss: 0.3291 - accuracy: 0.8774
# Epoch 797/1000
# 7/7 - 0s - loss: 0.3288 - accuracy: 0.8774
# Epoch 798/1000
# 7/7 - 0s - loss: 0.3295 - accuracy: 0.8726
# Epoch 799/1000
# 7/7 - 0s - loss: 0.3295 - accuracy: 0.8774
# Epoch 800/1000
# 7/7 - 0s - loss: 0.3287 - accuracy: 0.8726
# Epoch 801/1000
# 7/7 - 0s - loss: 0.3280 - accuracy: 0.8726
# Epoch 802/1000
# 7/7 - 0s - loss: 0.3279 - accuracy: 0.8774
# Epoch 803/1000
# 7/7 - 0s - loss: 0.3289 - accuracy: 0.8774
# Epoch 804/1000
# 7/7 - 0s - loss: 0.3283 - accuracy: 0.8726
# Epoch 805/1000
# 7/7 - 0s - loss: 0.3298 - accuracy: 0.8726
# Epoch 806/1000
# 7/7 - 0s - loss: 0.3282 - accuracy: 0.8726
# Epoch 807/1000
# 7/7 - 0s - loss: 0.3285 - accuracy: 0.8774
# Epoch 808/1000
# 7/7 - 0s - loss: 0.3298 - accuracy: 0.8774
# Epoch 809/1000
# 7/7 - 0s - loss: 0.3289 - accuracy: 0.8726
# Epoch 810/1000
# 7/7 - 0s - loss: 0.3287 - accuracy: 0.8774
# Epoch 811/1000
# 7/7 - 0s - loss: 0.3283 - accuracy: 0.8774
# Epoch 812/1000
# 7/7 - 0s - loss: 0.3287 - accuracy: 0.8726
# Epoch 813/1000
# 7/7 - 0s - loss: 0.3288 - accuracy: 0.8726
# Epoch 814/1000
# 7/7 - 0s - loss: 0.3287 - accuracy: 0.8726
# Epoch 815/1000
# 7/7 - 0s - loss: 0.3283 - accuracy: 0.8774
# Epoch 816/1000
# 7/7 - 0s - loss: 0.3287 - accuracy: 0.8821
# Epoch 817/1000
# 7/7 - 0s - loss: 0.3280 - accuracy: 0.8726
# Epoch 818/1000
# 7/7 - 0s - loss: 0.3284 - accuracy: 0.8726
# Epoch 819/1000
# 7/7 - 0s - loss: 0.3283 - accuracy: 0.8726
# Epoch 820/1000
# 7/7 - 0s - loss: 0.3288 - accuracy: 0.8774
# Epoch 821/1000
# 7/7 - 0s - loss: 0.3289 - accuracy: 0.8774
# Epoch 822/1000
# 7/7 - 0s - loss: 0.3283 - accuracy: 0.8774
# Epoch 823/1000
# 7/7 - 0s - loss: 0.3283 - accuracy: 0.8726
# Epoch 824/1000
# 7/7 - 0s - loss: 0.3284 - accuracy: 0.8774
# Epoch 825/1000
# 7/7 - 0s - loss: 0.3301 - accuracy: 0.8679
# Epoch 826/1000
# 7/7 - 0s - loss: 0.3280 - accuracy: 0.8774
# Epoch 827/1000
# 7/7 - 0s - loss: 0.3282 - accuracy: 0.8774
# Epoch 828/1000
# 7/7 - 0s - loss: 0.3280 - accuracy: 0.8726
# Epoch 829/1000
# 7/7 - 0s - loss: 0.3277 - accuracy: 0.8774
# Epoch 830/1000
# 7/7 - 0s - loss: 0.3277 - accuracy: 0.8774
# Epoch 831/1000
# 7/7 - 0s - loss: 0.3287 - accuracy: 0.8774
# Epoch 832/1000
# 7/7 - 0s - loss: 0.3279 - accuracy: 0.8774
# Epoch 833/1000
# 7/7 - 0s - loss: 0.3283 - accuracy: 0.8774
# Epoch 834/1000
# 7/7 - 0s - loss: 0.3285 - accuracy: 0.8726
# Epoch 835/1000
# 7/7 - 0s - loss: 0.3278 - accuracy: 0.8774
# Epoch 836/1000
# 7/7 - 0s - loss: 0.3290 - accuracy: 0.8774
# Epoch 837/1000
# 7/7 - 0s - loss: 0.3288 - accuracy: 0.8726
# Epoch 838/1000
# 7/7 - 0s - loss: 0.3279 - accuracy: 0.8726
# Epoch 839/1000
# 7/7 - 0s - loss: 0.3285 - accuracy: 0.8726
# Epoch 840/1000
# 7/7 - 0s - loss: 0.3289 - accuracy: 0.8774
# Epoch 841/1000
# 7/7 - 0s - loss: 0.3279 - accuracy: 0.8726
# Epoch 842/1000
# 7/7 - 0s - loss: 0.3275 - accuracy: 0.8774
# Epoch 843/1000
# 7/7 - 0s - loss: 0.3280 - accuracy: 0.8774
# Epoch 844/1000
# 7/7 - 0s - loss: 0.3274 - accuracy: 0.8774
# Epoch 845/1000
# 7/7 - 0s - loss: 0.3291 - accuracy: 0.8774
# Epoch 846/1000
# 7/7 - 0s - loss: 0.3277 - accuracy: 0.8774
# Epoch 847/1000
# 7/7 - 0s - loss: 0.3274 - accuracy: 0.8774
# Epoch 848/1000
# 7/7 - 0s - loss: 0.3284 - accuracy: 0.8679
# Epoch 849/1000
# 7/7 - 0s - loss: 0.3296 - accuracy: 0.8774
# Epoch 850/1000
# 7/7 - 0s - loss: 0.3273 - accuracy: 0.8774
# Epoch 851/1000
# 7/7 - 0s - loss: 0.3275 - accuracy: 0.8726
# Epoch 852/1000
# 7/7 - 0s - loss: 0.3285 - accuracy: 0.8726
# Epoch 853/1000
# 7/7 - 0s - loss: 0.3283 - accuracy: 0.8726
# Epoch 854/1000
# 7/7 - 0s - loss: 0.3285 - accuracy: 0.8726
# Epoch 855/1000
# 7/7 - 0s - loss: 0.3277 - accuracy: 0.8774
# Epoch 856/1000
# 7/7 - 0s - loss: 0.3274 - accuracy: 0.8726
# Epoch 857/1000
# 7/7 - 0s - loss: 0.3271 - accuracy: 0.8774
# Epoch 858/1000
# 7/7 - 0s - loss: 0.3275 - accuracy: 0.8679
# Epoch 859/1000
# 7/7 - 0s - loss: 0.3280 - accuracy: 0.8774
# Epoch 860/1000
# 7/7 - 0s - loss: 0.3271 - accuracy: 0.8726
# Epoch 861/1000
# 7/7 - 0s - loss: 0.3276 - accuracy: 0.8774
# Epoch 862/1000
# 7/7 - 0s - loss: 0.3285 - accuracy: 0.8679
# Epoch 863/1000
# 7/7 - 0s - loss: 0.3276 - accuracy: 0.8774
# Epoch 864/1000
# 7/7 - 0s - loss: 0.3287 - accuracy: 0.8726
# Epoch 865/1000
# 7/7 - 0s - loss: 0.3283 - accuracy: 0.8726
# Epoch 866/1000
# 7/7 - 0s - loss: 0.3270 - accuracy: 0.8774
# Epoch 867/1000
# 7/7 - 0s - loss: 0.3280 - accuracy: 0.8774
# Epoch 868/1000
# 7/7 - 0s - loss: 0.3271 - accuracy: 0.8774
# Epoch 869/1000
# 7/7 - 0s - loss: 0.3273 - accuracy: 0.8726
# Epoch 870/1000
# 7/7 - 0s - loss: 0.3273 - accuracy: 0.8774
# Epoch 871/1000
# 7/7 - 0s - loss: 0.3271 - accuracy: 0.8774
# Epoch 872/1000
# 7/7 - 0s - loss: 0.3276 - accuracy: 0.8774
# Epoch 873/1000
# 7/7 - 0s - loss: 0.3280 - accuracy: 0.8774
# Epoch 874/1000
# 7/7 - 0s - loss: 0.3278 - accuracy: 0.8726
# Epoch 875/1000
# 7/7 - 0s - loss: 0.3268 - accuracy: 0.8726
# Epoch 876/1000
# 7/7 - 0s - loss: 0.3273 - accuracy: 0.8774
# Epoch 877/1000
# 7/7 - 0s - loss: 0.3268 - accuracy: 0.8774
# Epoch 878/1000
# 7/7 - 0s - loss: 0.3274 - accuracy: 0.8726
# Epoch 879/1000
# 7/7 - 0s - loss: 0.3276 - accuracy: 0.8679
# Epoch 880/1000
# 7/7 - 0s - loss: 0.3282 - accuracy: 0.8774
# Epoch 881/1000
# 7/7 - 0s - loss: 0.3277 - accuracy: 0.8679
# Epoch 882/1000
# 7/7 - 0s - loss: 0.3279 - accuracy: 0.8774
# Epoch 883/1000
# 7/7 - 0s - loss: 0.3269 - accuracy: 0.8726
# Epoch 884/1000
# 7/7 - 0s - loss: 0.3281 - accuracy: 0.8726
# Epoch 885/1000
# 7/7 - 0s - loss: 0.3272 - accuracy: 0.8726
# Epoch 886/1000
# 7/7 - 0s - loss: 0.3273 - accuracy: 0.8726
# Epoch 887/1000
# 7/7 - 0s - loss: 0.3270 - accuracy: 0.8774
# Epoch 888/1000
# 7/7 - 0s - loss: 0.3279 - accuracy: 0.8774
# Epoch 889/1000
# 7/7 - 0s - loss: 0.3268 - accuracy: 0.8774
# Epoch 890/1000
# 7/7 - 0s - loss: 0.3272 - accuracy: 0.8726
# Epoch 891/1000
# 7/7 - 0s - loss: 0.3274 - accuracy: 0.8774
# Epoch 892/1000
# 7/7 - 0s - loss: 0.3266 - accuracy: 0.8821
# Epoch 893/1000
# 7/7 - 0s - loss: 0.3277 - accuracy: 0.8774
# Epoch 894/1000
# 7/7 - 0s - loss: 0.3266 - accuracy: 0.8679
# Epoch 895/1000
# 7/7 - 0s - loss: 0.3277 - accuracy: 0.8774
# Epoch 896/1000
# 7/7 - 0s - loss: 0.3268 - accuracy: 0.8774
# Epoch 897/1000
# 7/7 - 0s - loss: 0.3276 - accuracy: 0.8821
# Epoch 898/1000
# 7/7 - 0s - loss: 0.3270 - accuracy: 0.8774
# Epoch 899/1000
# 7/7 - 0s - loss: 0.3269 - accuracy: 0.8774
# Epoch 900/1000
# 7/7 - 0s - loss: 0.3267 - accuracy: 0.8774
# Epoch 901/1000
# 7/7 - 0s - loss: 0.3272 - accuracy: 0.8726
# Epoch 902/1000
# 7/7 - 0s - loss: 0.3277 - accuracy: 0.8774
# Epoch 903/1000
# 7/7 - 0s - loss: 0.3266 - accuracy: 0.8774
# Epoch 904/1000
# 7/7 - 0s - loss: 0.3264 - accuracy: 0.8774
# Epoch 905/1000
# 7/7 - 0s - loss: 0.3283 - accuracy: 0.8726
# Epoch 906/1000
# 7/7 - 0s - loss: 0.3266 - accuracy: 0.8774
# Epoch 907/1000
# 7/7 - 0s - loss: 0.3267 - accuracy: 0.8774
# Epoch 908/1000
# 7/7 - 0s - loss: 0.3269 - accuracy: 0.8726
# Epoch 909/1000
# 7/7 - 0s - loss: 0.3274 - accuracy: 0.8774
# Epoch 910/1000
# 7/7 - 0s - loss: 0.3266 - accuracy: 0.8774
# Epoch 911/1000
# 7/7 - 0s - loss: 0.3264 - accuracy: 0.8726
# Epoch 912/1000
# 7/7 - 0s - loss: 0.3265 - accuracy: 0.8774
# Epoch 913/1000
# 7/7 - 0s - loss: 0.3267 - accuracy: 0.8726
# Epoch 914/1000
# 7/7 - 0s - loss: 0.3264 - accuracy: 0.8774
# Epoch 915/1000
# 7/7 - 0s - loss: 0.3275 - accuracy: 0.8726
# Epoch 916/1000
# 7/7 - 0s - loss: 0.3267 - accuracy: 0.8774
# Epoch 917/1000
# 7/7 - 0s - loss: 0.3272 - accuracy: 0.8774
# Epoch 918/1000
# 7/7 - 0s - loss: 0.3265 - accuracy: 0.8774
# Epoch 919/1000
# 7/7 - 0s - loss: 0.3267 - accuracy: 0.8821
# Epoch 920/1000
# 7/7 - 0s - loss: 0.3262 - accuracy: 0.8726
# Epoch 921/1000
# 7/7 - 0s - loss: 0.3275 - accuracy: 0.8632
# Epoch 922/1000
# 7/7 - 0s - loss: 0.3269 - accuracy: 0.8774
# Epoch 923/1000
# 7/7 - 0s - loss: 0.3258 - accuracy: 0.8774
# Epoch 924/1000
# 7/7 - 0s - loss: 0.3269 - accuracy: 0.8726
# Epoch 925/1000
# 7/7 - 0s - loss: 0.3264 - accuracy: 0.8726
# Epoch 926/1000
# 7/7 - 0s - loss: 0.3273 - accuracy: 0.8821
# Epoch 927/1000
# 7/7 - 0s - loss: 0.3268 - accuracy: 0.8821
# Epoch 928/1000
# 7/7 - 0s - loss: 0.3272 - accuracy: 0.8774
# Epoch 929/1000
# 7/7 - 0s - loss: 0.3260 - accuracy: 0.8774
# Epoch 930/1000
# 7/7 - 0s - loss: 0.3261 - accuracy: 0.8774
# Epoch 931/1000
# 7/7 - 0s - loss: 0.3265 - accuracy: 0.8726
# Epoch 932/1000
# 7/7 - 0s - loss: 0.3262 - accuracy: 0.8726
# Epoch 933/1000
# 7/7 - 0s - loss: 0.3262 - accuracy: 0.8774
# Epoch 934/1000
# 7/7 - 0s - loss: 0.3267 - accuracy: 0.8726
# Epoch 935/1000
# 7/7 - 0s - loss: 0.3263 - accuracy: 0.8726
# Epoch 936/1000
# 7/7 - 0s - loss: 0.3265 - accuracy: 0.8774
# Epoch 937/1000
# 7/7 - 0s - loss: 0.3264 - accuracy: 0.8821
# Epoch 938/1000
# 7/7 - 0s - loss: 0.3272 - accuracy: 0.8679
# Epoch 939/1000
# 7/7 - 0s - loss: 0.3258 - accuracy: 0.8774
# Epoch 940/1000
# 7/7 - 0s - loss: 0.3266 - accuracy: 0.8774
# Epoch 941/1000
# 7/7 - 0s - loss: 0.3259 - accuracy: 0.8774
# Epoch 942/1000
# 7/7 - 0s - loss: 0.3266 - accuracy: 0.8774
# Epoch 943/1000
# 7/7 - 0s - loss: 0.3260 - accuracy: 0.8774
# Epoch 944/1000
# 7/7 - 0s - loss: 0.3262 - accuracy: 0.8821
# Epoch 945/1000
# 7/7 - 0s - loss: 0.3260 - accuracy: 0.8774
# Epoch 946/1000
# 7/7 - 0s - loss: 0.3263 - accuracy: 0.8774
# Epoch 947/1000
# 7/7 - 0s - loss: 0.3263 - accuracy: 0.8774
# Epoch 948/1000
# 7/7 - 0s - loss: 0.3272 - accuracy: 0.8821
# Epoch 949/1000
# 7/7 - 0s - loss: 0.3262 - accuracy: 0.8774
# Epoch 950/1000
# 7/7 - 0s - loss: 0.3258 - accuracy: 0.8774
# Epoch 951/1000
# 7/7 - 0s - loss: 0.3261 - accuracy: 0.8726
# Epoch 952/1000
# 7/7 - 0s - loss: 0.3261 - accuracy: 0.8726
# Epoch 953/1000
# 7/7 - 0s - loss: 0.3264 - accuracy: 0.8726
# Epoch 954/1000
# 7/7 - 0s - loss: 0.3263 - accuracy: 0.8821
# Epoch 955/1000
# 7/7 - 0s - loss: 0.3263 - accuracy: 0.8679
# Epoch 956/1000
# 7/7 - 0s - loss: 0.3273 - accuracy: 0.8726
# Epoch 957/1000
# 7/7 - 0s - loss: 0.3260 - accuracy: 0.8774
# Epoch 958/1000
# 7/7 - 0s - loss: 0.3258 - accuracy: 0.8726
# Epoch 959/1000
# 7/7 - 0s - loss: 0.3254 - accuracy: 0.8774
# Epoch 960/1000
# 7/7 - 0s - loss: 0.3264 - accuracy: 0.8821
# Epoch 961/1000
# 7/7 - 0s - loss: 0.3267 - accuracy: 0.8726
# Epoch 962/1000
# 7/7 - 0s - loss: 0.3255 - accuracy: 0.8774
# Epoch 963/1000
# 7/7 - 0s - loss: 0.3255 - accuracy: 0.8774
# Epoch 964/1000
# 7/7 - 0s - loss: 0.3261 - accuracy: 0.8774
# Epoch 965/1000
# 7/7 - 0s - loss: 0.3262 - accuracy: 0.8774
# Epoch 966/1000
# 7/7 - 0s - loss: 0.3255 - accuracy: 0.8774
# Epoch 967/1000
# 7/7 - 0s - loss: 0.3260 - accuracy: 0.8774
# Epoch 968/1000
# 7/7 - 0s - loss: 0.3257 - accuracy: 0.8774
# Epoch 969/1000
# 7/7 - 0s - loss: 0.3271 - accuracy: 0.8774
# Epoch 970/1000
# 7/7 - 0s - loss: 0.3260 - accuracy: 0.8774
# Epoch 971/1000
# 7/7 - 0s - loss: 0.3260 - accuracy: 0.8726
# Epoch 972/1000
# 7/7 - 0s - loss: 0.3257 - accuracy: 0.8774
# Epoch 973/1000
# 7/7 - 0s - loss: 0.3259 - accuracy: 0.8726
# Epoch 974/1000
# 7/7 - 0s - loss: 0.3252 - accuracy: 0.8726
# Epoch 975/1000
# 7/7 - 0s - loss: 0.3265 - accuracy: 0.8821
# Epoch 976/1000
# 7/7 - 0s - loss: 0.3258 - accuracy: 0.8726
# Epoch 977/1000
# 7/7 - 0s - loss: 0.3257 - accuracy: 0.8774
# Epoch 978/1000
# 7/7 - 0s - loss: 0.3257 - accuracy: 0.8774
# Epoch 979/1000
# 7/7 - 0s - loss: 0.3258 - accuracy: 0.8774
# Epoch 980/1000
# 7/7 - 0s - loss: 0.3259 - accuracy: 0.8774
# Epoch 981/1000
# 7/7 - 0s - loss: 0.3253 - accuracy: 0.8774
# Epoch 982/1000
# 7/7 - 0s - loss: 0.3255 - accuracy: 0.8726
# Epoch 983/1000
# 7/7 - 0s - loss: 0.3255 - accuracy: 0.8726
# Epoch 984/1000
# 7/7 - 0s - loss: 0.3256 - accuracy: 0.8679
# Epoch 985/1000
# 7/7 - 0s - loss: 0.3256 - accuracy: 0.8679
# Epoch 986/1000
# 7/7 - 0s - loss: 0.3267 - accuracy: 0.8726
# Epoch 987/1000
# 7/7 - 0s - loss: 0.3251 - accuracy: 0.8726
# Epoch 988/1000
# 7/7 - 0s - loss: 0.3250 - accuracy: 0.8774
# Epoch 989/1000
# 7/7 - 0s - loss: 0.3258 - accuracy: 0.8726
# Epoch 990/1000
# 7/7 - 0s - loss: 0.3252 - accuracy: 0.8774
# Epoch 991/1000
# 7/7 - 0s - loss: 0.3248 - accuracy: 0.8774
# Epoch 992/1000
# 7/7 - 0s - loss: 0.3252 - accuracy: 0.8726
# Epoch 993/1000
# 7/7 - 0s - loss: 0.3249 - accuracy: 0.8774
# Epoch 994/1000
# 7/7 - 0s - loss: 0.3258 - accuracy: 0.8726
# Epoch 995/1000
# 7/7 - 0s - loss: 0.3265 - accuracy: 0.8774
# Epoch 996/1000
# 7/7 - 0s - loss: 0.3247 - accuracy: 0.8774
# Epoch 997/1000
# 7/7 - 0s - loss: 0.3248 - accuracy: 0.8821
# Epoch 998/1000
# 7/7 - 0s - loss: 0.3248 - accuracy: 0.8774
# Epoch 999/1000
# 7/7 - 0s - loss: 0.3250 - accuracy: 0.8726
# Epoch 1000/1000
# 7/7 - 0s - loss: 0.3257 - accuracy: 0.8679

# %%
model.summary()
score_train = model.evaluate(X_train, y_train, verbose=1)
score_test = model.evaluate(X_test, y_test, verbose=1)
print('Model Accuracy(train) = ',score_train[1])
print('Model Accuracy(test) = ',score_test[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 10)                140
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 261
# Trainable params: 261
# Non-trainable params: 0
# _________________________________________________________________
# 7/7 [==============================] - 1s 2ms/step - loss: 0.3243 - accuracy: 0.8774
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4142 - accuracy: 0.8022
# Model Accuracy(train) =  0.8773584961891174
# Model Accuracy(test) =  0.8021978139877319

# %%
train_pred=model.predict(X_train)>0.5
test_pred=model.predict(X_test)>0.5

# %% [markdown]
# ## **Evaluate using various metrics**

# %%
# Confusion matrices for train and test 
print(confusion_matrix(y_train,train_pred))
print(confusion_matrix(y_test,test_pred))
# Out:
# [[ 79  15]
#  [ 11 107]]
# [[32 12]
#  [ 6 41]]

# %%
# Get the confusion matrix for both train and test

labels = ['No heart disease.', 'Heart disease.']
cm = confusion_matrix(y_train,train_pred)

ax= plt.subplot()
sns.heatmap(cm, annot=True,ax=ax) #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix for heart desease(Train).')
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)
# Out:
# [Text(0, 0.5, 'No heart disease.'), Text(0, 1.5, 'Heart disease.')]

# %%
# Get the confusion matrix for both train and test

labels = ['No heart disease.', 'Heart disease.']
cm = confusion_matrix(y_test,test_pred)

ax= plt.subplot()
sns.heatmap(cm, annot=True,ax=ax) #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix for heart desease(Test).')
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)
# Out:
# [Text(0, 0.5, 'No heart disease.'), Text(0, 1.5, 'Heart disease.')]

# %%
# Print the classification report for train and test
print(classification_report(y_train,train_pred))
print("\n")
print(classification_report(y_test,test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86        94
#            1       0.88      0.91      0.89       118
#
#     accuracy                           0.88       212
#    macro avg       0.88      0.87      0.88       212
# weighted avg       0.88      0.88      0.88       212
#
#
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.73      0.78        44
#            1       0.77      0.87      0.82        47
#
#     accuracy                           0.80        91
#    macro avg       0.81      0.80      0.80        91
# weighted avg       0.81      0.80      0.80        91

# %%
roc_auc_score(y_train,train_pred)
# Out:
# 0.8736025964659215

# %%
roc_auc_score(y_test,test_pred)
# Out:
# 0.799806576402321

# %% [markdown]
# ## **ROC curve for train and test**

# %%
fpr_train, tpr_train, thresholds_train = roc_curve(y_train, train_pred)
auc_train = auc(fpr_train, tpr_train)
plt.figure
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_train, tpr_train, label='Keras (area = {:.3f})'.format(auc_train))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
fpr_test, tpr_test, thresholds_test = roc_curve(y_test, test_pred)
auc_test = auc(fpr_test, tpr_test)
plt.figure
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_test, tpr_test, label='Keras (area = {:.3f})'.format(auc_test))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# The model performs well on both train and test data based on accuracy but false positives and false negatives can't be avoided in case of health related problems therefore this is not the optimal model.
